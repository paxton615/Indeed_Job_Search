# %%
import requests
import bs4
from bs4 import BeautifulSoup
import re
import pandas as pd
pd.options.display.max_rows = 5000 #(设定能显示的行数)

# %% [markdown]
# ###### Main cities in the UK

# %%
cities = 'London '
# "London ,Manchester,Birmingham,Wolverhampton ,Leeds, Bradford ,Glasgow ,Southampton,Portsmouth ,Liverpool ,Newcastle ,Nottingham ,Sheffield,Bristol,Belfast,Leicester"
city_lst = []
for i in cities.split(','):
    city_lst.append(i.strip())
    
print(city_lst)
# Out:
# ['London']

# %% [markdown]
# ##### Checking requests status here

# %%
url = 'https://www.indeed.co.uk/jobs?q=business+development&l=london&start=0'
# url = 'https://www.indeed.co.uk/jobs?q=junior+data+scientist&l=london&start=10' # Every page is 10*x, page3=20 ...
r = requests.get(url)
r.status_code
# Out:
# 200

# %%
# Create soup and have a glimpse
soup = BeautifulSoup(r.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <meta content="text/html;charset=utf-8" http-equiv="content-type"/>
#   <script src="//d3fw5vlhllyvee.cloudfront.net/s/7476d99/en_GB.js" type="text/javascript">
#   </script>
#   <link href="//d3fw5vlhllyvee.cloudfront.net/s/29590d8/jobsearch_all.css" rel="stylesheet" type="text/css"/>
#   <link href="https://www.indeed.co.uk/rss?q=business+development&amp;l=london" rel="alternate" title="Business Development Jobs, vacancies in London" type="application/rss+xml"/>
#   <link href="/m/jobs?q=business+development&amp;l=london" media="only screen and (max-width: 640px)" rel="alternate"/>
#   <link href="/m/jobs?q=business+development&amp;l=london" media="handheld" rel="alternate"/>
#   <script type="text/javascript">
#    if (typeof window['closureReadyCallbacks'] == 'undefined') {
# window['closureReadyCallbacks'] = [];
# }
#
# function call_when_jsall_loaded(cb) {
# if (window['closureReady']) {
# cb();
# } else {
# window['closureReadyCallbacks'].push(cb);
# }
# }
#   </script>
#   <meta content="1" name="ppstriptst"/>
#   <script>
#    var _scriptDownloadCount = 0;
# var _retryDownload = function() {
# var script = document.createElement('script');
# var path = '//d3fw5vlhllyvee.cloudfront.net/s/a537211/jobsearch-all-compiled.js';
# script.async = false;
# script.src = path;
# script.onerror=_onMainJSBundleError;
# document.head.appendChild(script);
# };
# var _onMainJSBundleError = function() {
# try {
#
# // for failed downloads, we want to retry the download up to 5 times
# if (_scriptDownloadCount < 4) {
# _scriptDownloadCount++;
# _retryDownload();
# return;
# }
#
# // if we've exhausted all retries, send a ping to log the failure
# var img = document.createElement("img");
# var tk = "1eo50shvu98sq800"; // tk
# img.src = "/rpc/log?a=jasxJsLoadError&tk=" + tk;
# document.head.appendChild(img);
# document.head.removeChild(img);
#
# } catch(e) {}
# }
#   </script>
#   <script crossorigin="anonymous" onerror="_onMainJSBundleError()" src="//d3fw5vlhllyvee.cloudfront.net/s/a537211/jobsearch-all-compiled.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var searchUID = '1eo50shvu98sq800';
# var tk = '1eo50shvu98sq800';
#
# var loggedIn = false;
# var dcmPayload = 'jobse0;jobal0;viewj0;savej0;8232301';
# var myindeed = true;
# var userEmail = '';
# var tellFriendEmail = '';
# var globalLoginURL = 'https:\/\/www.indeed.co.uk\/account\/login?dest=%2Fjobs%3Fq%3Dbusiness%2Bdevelopment%26l%3Dlondon%26start%3D0';
# var globalRegisterURL = 'https:\/\/www.indeed.co.uk\/account\/register?dest=%2Fjobs%3Fq%3Dbusiness%2Bdevelopment%26l%3Dlondon%26start%3D0';
# var searchKey = 'df784e340ae11497';
# var searchState = 'q=business+development&amp;l=london&amp;start=0';
# var searchQS = 'q=business+development&l=london&start=0';
# var eventType = 'jobsearch';
# var locale = 'en_GB';
# function clk(id) { var a = document.getElementById(id); var hr = a.href; var si = a.href.indexOf('&jsa='); if (si > 0) return; var jsh = hr + '&tk=1eo50shvu98sq800&jsa=6798'; a.href = jsh; }
# function sjomd(id) { var a = document.getElementById(id); var hr = a.href; var ocs = hr.indexOf('&oc=1'); if (ocs < 0) return; var oce = ocs + 5; a.href = hr.substring(0, ocs) + hr.substring(oce); }
# function sjoc(id, sal) { var a = document.getElementById(id); a.href = a.href + '&oc=1&sal='+sal; }
# function ptk(st,p) {document.cookie = 'PTK="tk=1eo50shvu98sq800&type=jobsearch&subtype='+st+(p?'&'+p:'')+'"; path=/';}
# function rbptk(st, c, p) { ptk(st, 'cat='+c+(p?'&p='+p:''));}
#   </script>
#   <script type="text/javascript">
#    function loadJSAsync( ) {
# for ( var i = 0; i < arguments.length; i++ ) {
# var url = arguments[i];
# (function() {
# var s = document.createElement("script"), el = document.getElementsByTagName("script")[0];
# s.async = true;
# s.src = url;
# el.parentNode.insertBefore(s, el);
# })();
# }
# }
#   </script>
#   <meta content="Apply to Business Development jobs now hiring in London on Indeed.co.uk, the world's largest job site." name="description"/>
#   <meta content="Business Development Jobs, vacancies in London, London careers, London employment, London job listings, London job search, London search engine, work in London" name="keywords"/>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <link href="/Business-Development-jobs-in-London" rel="canonical"/>
#   <link href="/jobs?q=business+development&amp;l=london&amp;start=10" rel="next">
#    <script src="https://d3fw5vlhllyvee.cloudfront.net/mosaic-common/dist/3e6b6d628c72a2028beb/scripts/shim.js?cacheKey=1" type="text/javascript">
#    </script>
#    <link href="//d3fw5vlhllyvee.cloudfront.net/s/94cc35f/jobCardHolisticRedesign.css" rel="stylesheet" type="text/css">
#     <style type="text/css">
#      #resultsBody #pageContent #resultsCol .row .salarySnippet{padding-top:0.5rem}
#     </style>
#     <script type="text/javascript">
#      var dcmPayload = 'jobse0;jobal0;viewj0;savej0;8232301';
# var indeedCsrfToken = 'UCdD5ETvf5vZ9YjPZO3UJrkwSiJqB9h6';
# var hashedCsrfToken = '330bb5f7052796f63780270ccccaf0f3';
#     </script>
#     <style type="text/css">
#      body.janus #resultsCol .clickcard .jobtitle a,body.janus #resultsCol .clickcard a.jobtitle{text-decoration:none}body.janus #resultsCol .clickcard:hover .jobtitle a,body.janus #resultsCol .clickcard:hover a.jobtitle{text-decoration:underline}
#     </style>
#     <style type="text/css">
#      body.janus #resultsCol .pagination{display:flex;justify-content:center;margin-right:0 !important}body.janus #resultsCol .pagination .pagination-list{display:flex;padding-left:0;list-style:none}body.janus #resultsCol .pagination .pagination-list li{margin-right:16px}body.janus #resultsCol .pagination .pagination-list li a{margin-left:0 !important;text-decoration:none;display:block}body.janus #resultsCol .pagination .pagination-list li a span.pn{display:flex;justify-content:center;align-items:center;background:#ececec;color:#2d2d2d !important;font-weight:400 !important;border-radius:8px;height:40px;width:40px;font-size:1.125rem !important}body.janus #resultsCol .pagination .pagination-list li a span.pn span.np{display:flex}body.janus #resultsCol .pagination .pagination-list li a span.pn:hover{background:#e3e3e3;box-shadow:inset 0 1px 4px rgba(0,0,0,0.1);border:1px #085ff7}body.janus #resultsCol .pagination .pagination-list li a span.pn:active:focus{background:#d9d9d9;box-shadow:inset 0 1px 4px rgba(0,0,0,0.1);border:1px #085ff7}body.janus #resultsCol .pagination .pagination-list li a span.pn:active{background:#d9d9d9;box-shadow:inset 0 1px 4px rgba(0,0,0,0.1)}body.janus #resultsCol .pagination .pagination-list li b{background:#4b4b4b;color:#fff !important;font-weight:700;border-radius:8px;height:40px;width:40px;font-size:1.125rem !important;display:flex;align-items:center;justify-content:center;margin-left:0 !important;text-decoration:none}body.janus #resultsCol .pagination .pagination-list li a:focus,body.janus #resultsCol .pagination .pagination-list li b:focus{outline:0;border-radius:9px;border:1px #085ff7;box-shadow:inset 0 2px 0 transparent,0 0 0 2px #fff,0 0 0 3px #085ff7}[dir="ltr"] body.janus #resultsCol .pagination .pagination-list li:last-child{margin-right:0}[dir="rtl"] body.janus #resultsCol .pagination .pagination-list li:first-child{margin-right:0}
#     </style>
#     <style>
#      .serp-UrgentlyHiringMessage{display:-ms-flexbox;display:-webkit-flex;display:flex;-webkit-box-align:center;-ms-flex-align:center;align-items:center}.serp-UrgentlyHiringMessage-icon{margin-right:0.3125rem;height:1rem;width:1rem}.serp-UrgentlyHiringMessage-text{font-size:0.75rem;line-height:1.25rem}.serpvj-UrgentlyHiringMessage{display:-ms-flexbox;display:-webkit-flex;display:flex;-webkit-box-align:center;-ms-flex-align:center;align-items:center}.serpvj-UrgentlyHiringMessage-icon{margin-right:0.5rem;height:1.25rem;width:1.25rem}.serpvj-UrgentlyHiringMessage-text{font-size:0.875rem;line-height:1.25rem;font-weight:bold}.jasxrefreshcombotst .serpvj-UrgentlyHiringMessage-text{color:#2d2d2d}
#     </style>
#     <style type="text/css">
#      body #resultsBody #pageContent #resultsCol .row.unifiedRow .jobCardReqContainer{padding-top:1rem}body #resultsBody #pageContent #resultsCol .row.unifiedRow .jobCardReqContainer+.jobCardShelfContainer,body #resultsBody #pageContent #resultsCol .row.unifiedRow .jobCardReqContainer+.summary,body #resultsBody #pageContent #resultsCol .row.unifiedRow .jobCardReqContainer+.jobsearch-SerpJobCard-footer .result-link-bar-container{padding-top:1rem}body #resultsBody #pageContent #resultsCol .row.unifiedRow .jobCardReqHeader{font-size:1rem;line-height:1.5rem;font-weight:700;letter-spacing:0;color:#2d2d2d}body #resultsBody #pageContent #resultsCol .row.unifiedRow .jobCardReqHeader+.jobCardReqList .jobCardReqItem:first-of-type{padding-top:0.5rem}body #resultsBody #pageContent #resultsCol .row.unifiedRow .jobCardReqItem:first-of-type{padding-top:0}body #resultsBody #pageContent #resultsCol .row.unifiedRow .jobCardReqItem,body #resultsBody #pageContent #resultsCol .row.unifiedRow .jobCardReqMore{font-size:0.875rem;line-height:1.25rem;padding-top:0.5rem;color:#2d2d2d}body #resultsBody #pageContent #resultsCol .row.unifiedRow .jobCardReqAddtlString{padding-left:0.75rem}
#     </style>
#     <style>
#      [dir] body .icl-Button,[dir] body .icl-Button--primary{border-radius:0.5rem}[dir] body .icl-Button--primary{background-color:#085ff7;border-color:transparent;color:#fff}[dir] body .icl-Button--primary:hover{background:#0750cf;border-color:transparent;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.2);color:#fff;cursor:pointer}[dir] body .icl-Button--primary:focus{background:#0750cf;border-color:transparent;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.2),0 0 0 2px #fff,0 0 0 3px #085ff7;color:#fff;outline:none}[dir] body .icl-Button--primary:active{background:#0648bc;border-color:transparent;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.2);color:#fff}[dir] body .icl-Button--primary:hover:focus{outline:none;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.2),0 0 0 2px #fff,0 0 0 3px #085ff7}[dir] body .icl-Button--primary:hover:focus:active{box-shadow:none;outline:none}[dir] body .icl-Button--secondary{background-color:#ececec !important;border-color:transparent !important;color:#2d2d2d !important;border:0 !important;padding:0.5rem 1.25rem !important}[dir] body .icl-Button--secondary:hover{background:#e3e3e3 !important;border-color:transparent !important;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.1) !important;color:#2d2d2d !important;cursor:pointer}[dir] body .icl-Button--secondary:focus{background:#e3e3e3 !important;border-color:transparent !important;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.1),0 0 0 2px #fff,0 0 0 3px #085ff7 !important;color:#2d2d2d !important;outline:none !important}[dir] body .icl-Button--secondary:active{background:#d9d9d9 !important;border-color:transparent !important;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.1) !important;color:#2d2d2d !important}[dir] body .icl-Button--secondary:hover:focus{outline:none !important;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.1),0 0 0 2px #fff,0 0 0 3px #085ff7 !important}[dir] body .icl-Button--secondary:hover:focus:active{box-shadow:none !important;outline:none !important}body.janus table .footerCta.greyBar [dir] .icl-Button.cta_button.blue{border-radius:0.5rem !important;background-color:#085ff7 !important;border-color:transparent !important;color:#fff !important}body.janus table .footerCta.greyBar [dir] .icl-Button.cta_button.blue:hover{background:#0750cf !important;border-color:transparent !important;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.2) !important;color:#fff !important;cursor:pointer}body.janus table .footerCta.greyBar [dir] .icl-Button.cta_button.blue:focus{background:#0750cf !important;border-color:transparent !important;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.2),0 0 0 2px #fff,0 0 0 3px #085ff7 !important;color:#fff !important;outline:none !important}body.janus table .footerCta.greyBar [dir] .icl-Button.cta_button.blue:active{background:#0648bc !important;border-color:transparent !important;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.2) !important;color:#fff !important}body.janus table .footerCta.greyBar [dir] .icl-Button.cta_button.blue:hover:focus{outline:none !important;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.2),0 0 0 2px #fff,0 0 0 3px #085ff7 !important}body.janus table .footerCta.greyBar [dir] .icl-Button.cta_button.blue:hover:focus:active{box-shadow:none !important;outline:none !important}[dir] .gnav div.gnav-DesktopHeader.is-small-header{border-bottom:0 !important}#hiring-event-container-iframe{border-radius:0.5rem}div.mosaic-provider-jsfe-career-questions .faq-accordion-item{border-color:#d4d2d0}div.mosaic-provider-jsfe-career-questions .yes-no-feedback-btn{border-radius:0.5rem;background-color:#ececec;border-color:transparent;color:#2d2d2d;border:0}div.mosaic-provider-jsfe-career-questions .yes-no-feedback-btn:hover{background:#e3e3e3;border-color:transparent;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.1);color:#2d2d2d;cursor:pointer}div.mosaic-provider-jsfe-career-questions .yes-no-feedback-btn:focus{background:#e3e3e3;border-color:transparent;box-shadow:inse ...
#     </style>
#     <style>
#      .vjs-spb{position:relative;width:calc(100% + 48px);padding-top:20%;margin:-16px -24px 16px;background-size:cover;background-repeat:no-repeat}.vjs-spb-tag{position:absolute;right:4px;bottom:4px;font-size:0.5625rem;color:#4b4b4b;padding:2px 8px;background:rgba(255,255,255,0.8);border-radius:16px}#vjs-header-jobinfo{flex-wrap:wrap}#vjs-header-jobinfo #vjs-cmL+#vjs-jobinfo{flex-grow:1;width:0}
#     </style>
#     <link href="//d3fw5vlhllyvee.cloudfront.net/s/712a27b/Grid.css" rel="stylesheet" type="text/css">
#      <link href="//d3fw5vlhllyvee.cloudfront.net/s/cd7ca1d/Icon.css" rel="stylesheet" type="text/css">
#       <link href="//d3fw5vlhllyvee.cloudfront.net/s/56b285a/jasx-serp.css" rel="stylesheet" type="text/css">
#        <link href="//d3fw5vlhllyvee.cloudfront.net/s/c243447/salarylegaldisclaimer.css" rel="stylesheet" type="text/css"/>
#        <link href="//d3fw5vlhllyvee.cloudfront.net/s/05fda91/salaryestimates.css" rel="stylesheet" type="text/css"/>
#        <style type="text/css">
#         #resultsCol { padding-top: 0; }
# .searchCount { margin-top: 6px; }
# .showing { padding-top: 9px; padding-bottom: 9px; }
#
# .brdr { height: 1px; overflow: hidden; background-color: #ccc; }
#
# /* Tall window sizes */
# @media only screen and (min-height:780px){
# .showing { padding-bottom: 0; }
# }
#
# /* Wide window sizes */
# @media only screen and (min-width:1125px){
# .brdr  { margin-left: 12px; margin-right: 12px; }
# }
#
# a,a:link,.link,.btn,.btn:hover{text-decoration:none}a:hover,.link:hover{text-decoration:underline}.dya-container a{text-decoration:underline !important}
#        </style>
#        <script>
#         initJavascriptGroups({"73c1c24c17a1585cab090f60f8c5fc79c788b32cc9d81dc26199186f634c3923":[-1,null],"c999997ba6aa1b6881f335b3479ff7c77095d80af583ea479885b3e47b9cf726":[-1,null],"25b54f97c57c2a255b45d04ac4c971c0bf472556fdbe43828ac79e0968631ebb":[-1,null],"33c702625b69a177bde1650dce2a34feff29f3cfb8e30f8d00ab9526205b0ed4":[1,null],"80f582faf820a99d93c3a25b76db7b7a44cccd5d68f6fd53d1352cd0a45d42cc":[-1,null],"b6f0433c248484865fcf38b346f2c5af467936919986b2260ba10e925860158a":[2,null],"90981c400895faedd3e169efce6f570e2bd54b731fe0a8ccd4ea35853c856254":[-1,null],"4dc0081a9fa299429499c75533359d2c1b3359658955a46a632305adbdfcb589":[6,null],"6d23eea71158691303229243140eaac28d46283974abf8ede52556b9431fedf5":[-1,"sponsoredGray"],"5f4715d89442162447ad23a85839631e9e84db91c8ac165fd783105450b1ba26":[-1,null],"578033ef854ff6ed4a8c67b1c26d2b56566a03d423cac2e93d0799e733c88421":[-1,null],"efa89b73720c215b428e0cf8114a311f703342c7195c46d282c062bcdeab4766":[-1,null],"40a9f173a14ebbbdac25c0d95ed4d0f04a98b9aeee1acf5e9d5b1a8060d0398f":[-1,null],"7aa3047cbd2757fcf2a0147286062de8780277da2187cb35692ec8d902e377ee":[-1,0],"a350dab82c5df4e9ed69d047c8f6efcdde0f4a3b0a91cdc78a9b6fa310f9df9a":[2,["jobse0","jobal0","viewj0","savej0","8232301"]],"618eb58e0797fb61e6e2f35cbc17f5b1f830af0f0e07fd9fcdb1d2033968aad7":[1,null],"78b65fcdcde593fe9bc311aa67e58a68dba24f817c1f93576cf4bb0083938dfa":[1,null],"7f10ee5e41f69dcbd4f45fd84211f69e006c6fd60c4e8107e218d33c9f54da1c":[-1,null],"497283cccc19cba4b0a929496834fca9b8774fd0e6ae0f3b97fcde60af98252f":[-1,[]]});
# setRecentJobStylingEnabled(false);
#
# function onLoadHandler() {
#
# document.js.reset();
# jobSeenInit('1eo50shvu98sq800', [{
# 'jobClassName': 'result',
# 'scanIta': true,
# 'containsSponsored': true,
# 'context': ''
# }]);
#
# if ( document.radius_update ) { document.radius_update.reset(); }
#
#
# initJobsearchUnloadBeacon('1eo50shvu98sq800');
#
# initDwellPerformanceLogging('1eo50shvu98sq800', 'jasx');
# initWindowDwellLogging('jasx', '1eo50shvu98sq800', 'serp');
#
# initSponsoredJobScreenerQuestions();
#
# initIndeedApply('https://www.indeed.co.uk');
#
# }
#
# initLogInitialUserInteraction('1eo50shvu98sq800', 'serp');
#
# window.onload = onLoadHandler;
#        </script>
#        <link href="android-app://com.indeed.android.jobsearch/https/www.indeed.co.uk/m/jobs?q=business+development&amp;l=london&amp;start=0" rel="alternate"/>
#        <title>
#         Business Development Jobs in London - November 2020 | Indeed.co.uk
#        </title>
#        <style>
#         body.janus table #resultsCol .related_searches .rightBorder:after{content:none}body.janus #resultsCol .related_searches>div:first-child{margin-bottom:1rem}.related_searches>div:first-child>b:not([class]){color:#2d2d2d;display:block;font-size:1.125rem;font-weight:bold;letter-spacing:-0.06px;line-height:1.5rem;margin:0 0 1rem}.related_searches>div:first-child li{margin-bottom:0.5rem}.related_searches>div:first-child a{background-color:#ececec;background-image:url("data:image/svg+xml;charset=utf8,%3Csvg width='16' height='16' viewBox='0 0 16 16' fill='none' xmlns='http://www.w3.org/2000/svg'%3E%3Cpath fill-rule='evenodd' clip-rule='evenodd' d='M10.3333 9.33333H9.80667L9.62 9.15333C10.2733 8.39333 10.6667 7.40667 10.6667 6.33333C10.6667 3.94 8.72667 2 6.33333 2C3.94 2 2 3.94 2 6.33333C2 8.72667 3.94 10.6667 6.33333 10.6667C7.40667 10.6667 8.39333 10.2733 9.15333 9.62L9.33333 9.80667V10.3333L12.6667 13.66L13.66 12.6667L10.3333 9.33333ZM6.33337 9.33334C4.67337 9.33334 3.33337 7.99334 3.33337 6.33334C3.33337 4.67334 4.67337 3.33334 6.33337 3.33334C7.99337 3.33334 9.33337 4.67334 9.33337 6.33334C9.33337 7.99334 7.99337 9.33334 6.33337 9.33334Z' fill='%232D2D2D'/%3E%3C/svg%3E");background-position:0.5rem 50%;background-repeat:no-repeat;border-radius:0.5rem;display:inline-block;font-size:0.875rem;font-weight:bold;line-height:1.25rem;min-height:36px;padding:0.5rem 0.75rem 0.5rem 2rem}.related_searches>div:first-child a:hover{background-color:#e3e3e3;box-shadow:inset 0 1px 0.25rem rgba(0,0,0,0.1);cursor:pointer;text-decoration:none}.related_searches>div:first-child a:focus{outline:0;box-shadow:inset 0 1px 0.25rem rgba(0,0,0,0.2),0 0 0 2px #fff,0 0 0 3px #085ff7}.related_searches>div:first-child a:active{background-color:#d9d9d9;box-shadow:inset 0 1px 0.25rem rgba(0,0,0,0.1);color:#2d2d2d}#resultsCol .related_searches .related_searches_list ul a{color:#2d2d2d !important}body.janus #resultsCol .related_searches a{color:#2d2d2d !important}[dir] body.janus .relatedQuerySpacing table td a{color:#2d2d2d !important}body.janus #resultsCol .related_searches ul .rightBorder{margin-right:0.5rem}body.janus #resultsCol .related_searches ul .rightBorder:last-of-type{margin-right:0}body.janus table #resultsCol .related_searches{padding:1.5rem 0 0}.related_searches_list+style+.related_searches_list{border-top:1px solid #ececec;padding-top:1rem;margin-top:1rem}div.related_searches>div:first-child{font-size:0}div.related_searches>div:first-child>a{margin-right:0.5rem;margin-bottom:0.5rem}div.related_searches>div:first-child>a:last-of-type{margin-right:0}.relatedQuerySpacing b{color:#2d2d2d;display:block;font-size:1.125rem;font-weight:bold;letter-spacing:-0.06px;line-height:1.5rem;margin:0 0 1rem}.relatedQuerySpacing ul.relatedQueries-listView-pageLast{padding:0;column-count:initial;overflow:visible}.relatedQuerySpacing ul.relatedQueries-listView-pageLast a[href]{background-color:#ececec;background-image:url("data:image/svg+xml;charset=utf8,%3Csvg width='16' height='16' viewBox='0 0 16 16' fill='none' xmlns='http://www.w3.org/2000/svg'%3E%3Cpath fill-rule='evenodd' clip-rule='evenodd' d='M10.3333 9.33333H9.80667L9.62 9.15333C10.2733 8.39333 10.6667 7.40667 10.6667 6.33333C10.6667 3.94 8.72667 2 6.33333 2C3.94 2 2 3.94 2 6.33333C2 8.72667 3.94 10.6667 6.33333 10.6667C7.40667 10.6667 8.39333 10.2733 9.15333 9.62L9.33333 9.80667V10.3333L12.6667 13.66L13.66 12.6667L10.3333 9.33333ZM6.33337 9.33334C4.67337 9.33334 3.33337 7.99334 3.33337 6.33334C3.33337 4.67334 4.67337 3.33334 6.33337 3.33334C7.99337 3.33334 9.33337 4.67334 9.33337 6.33334C9.33337 7.99334 7.99337 9.33334 6.33337 9.33334Z' fill='%232D2D2D'/%3E%3C/svg%3E");background-position:0.5rem 50%;background-repeat:no-repeat;border-radius:0.5rem;display:inline-block;font-size:0.875rem;font-weight:bold;line-height:1.25rem;min-height:36px;padding:0.5rem 0.75rem 0.5rem 2rem;color:#2d2d2d !important}.relatedQuerySpacing ul.relatedQueries-listView-pageLast a[href]:hover{background-color:#e3e3e3;box-shadow ...
#        </style>
#        <style>
#         .inwrap .popover-input-locationtst{height:2.625rem;border-radius:0.1875rem;border-style:solid;border-width:0.125rem;padding-left:0.375rem;margin-top:0.3125rem;font-size:0.875rem}body .popover-form-locationtst .popover-input-locationtst[disabled],body .popover-form-locationtst .popover-input-locationtst[disabled]:active,body .popover-form-locationtst .popover-input-locationtst[disabled]:focus{border-color:#d6d6d6;color:#909090;box-shadow:none}:root .icl-TextInput-control,:root .popover-input-locationtst{color:#2d2d2d;border-color:#d4d2d0;color:#2d2d2d !important}:root .icl-TextInput-control:active,:root .icl-TextInput-control:focus,:root .popover-input-locationtst:active,:root .popover-input-locationtst:focus{border-color:#2557a7 !important}:root .icl-Button--secondary{border-color:#2557a7 !important;color:#2557a7 !important;transition:background-color 180ms ease-out,border-color 180ms ease-out}:root .icl-Button--secondary:active,:root .icl-Button--secondary:focus,:root .icl-Button--secondary:hover{background-color:unset !important}:root .icl-Button--secondary:active,:root .icl-Button--secondary:hover{border-color:#0d2d5e !important;color:#0d2d5e !important}:root .icl-Button--secondary:focus{box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.1),0 0 0 0.125rem #fff,0 0 0 0.1875rem #2557a7;border-color:#2557a7 !important}:root #cmp-root #cmp-footer input[type='submit'],:root .icl-Button--tertiary{border-color:#d4d2d0 !important;color:#2557a7 !important;transition:background-color 180ms ease-out,border-color 180ms ease-out}:root #cmp-root #cmp-footer input[type='submit']:active,:root #cmp-root #cmp-footer input[type='submit']:focus,:root #cmp-root #cmp-footer input[type='submit']:hover,:root .icl-Button--tertiary:active,:root .icl-Button--tertiary:focus,:root .icl-Button--tertiary:hover{background-color:unset !important}:root #cmp-root #cmp-footer input[type='submit']:active,:root #cmp-root #cmp-footer input[type='submit']:hover,:root .icl-Button--tertiary:active,:root .icl-Button--tertiary:hover{border-color:#949494 !important;color:#0d2d5e !important}:root #cmp-root #cmp-footer input[type='submit']:focus,:root .icl-Button--tertiary:focus{box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.1),0 0 0 0.125rem #fff,0 0 0 0.1875rem #2557a7}:root .icl-Icon--blue{fill:#2557a7}:root .icl-Card--hasBorder,:root .jobsearch-JobComponent-bottomDivider{border-color:#f3f2f1}:root .jamodal-gdpr,:root .mosaic-provider-reportcontent .report-content-legal-tos{color:#767676}:root #jamodal-email{color:#2d2d2d !important}:root #jamodal-email:active,:root #jamodal-email:focus{border-color:#2557a7 !important}:root .jamodal-heading{color:#2d2d2d}:root .jamodal-heading-container{border-bottom:0.125rem solid #faf9f8}:root #cmp-root #cmp-discovery a,:root #cmp-root #cmp-page .cmp-breadcrumb li a,:root #cmp-root .sal-job-openings-link,:root .femp_links,:root .femp_links div,:root a:not(.gnav-SkipNavLink):not(.icl-Button),:root a:not(.gnav-SkipNavLink):not(.icl-Button):link,:root body.janus #resultsBody #pageContent #resultsCol .result .sign-in-container .ws_content a{color:#2557a7 !important}:root .ws_content{border:none;background-color:#faf9f8 !important}:root .jobsearch-ViewJobLayout .icl-Button--whatWhere,:root body.janus table #jobsearch.jsf .inwrapBorder .input_submit{background-color:#2557a7 !important;border-color:#2557a7 !important;transition:background-color 200ms ease-out,border-color 200ms ease-out;font-size:0.875rem;font-weight:600}:root .jobsearch-ViewJobLayout .icl-Button--whatWhere:hover,:root body.janus table #jobsearch.jsf .inwrapBorder .input_submit:hover{background-color:#0d2d5e !important;border-color:#0d2d5e !important}:root .jobsearch-ViewJobLayout .icl-Button--whatWhere:active,:root body.janus table #jobsearch.jsf .inwrapBorder .input_submit:active{background-color:#0d2d5e !important;color:#fff !important;border-color:#0d2d5e !important}:root .jobsearch-ViewJobLayout .icl-Button--whatWhere:focus,:root body.janus table #jobsearch ...
#        </style>
#        <style>
#         .jobCardShelfContainer .jobCardShelf{display:flex;flex-wrap:wrap}.jobCardShelfContainer .jobCardShelf .jobCardShelfItem{align-items:center;display:flex !important}.jobCardShelfContainer .jobCardShelf .jobCardShelfItem span.jobCardShelfIcon{display:none !important}.jobCardShelfContainer .jobCardShelf .jobCardShelfItem .iaLabel{color:#2d2d2d !important;flex-basis:calc(100% -28px)}[dir='ltr'] .jobCardShelfContainer .jobCardShelf .jobCardShelfItem.earlyApply::before,[dir='ltr'] .jobCardShelfContainer .jobCardShelf .jobCardShelfItem.indeedApply::before,[dir='ltr'] .jobCardShelfContainer .jobCardShelf .jobCardShelfItem.manyApplies::before,[dir='ltr'] .jobCardShelfContainer .jobCardShelf .jobCardShelfItem.openInterviews::before,[dir='ltr'] .jobCardShelfContainer .jobCardShelf .jobCardShelfItem.responsiveEmployer::before,[dir='ltr'] .jobCardShelfContainer .jobCardShelf .jobCardShelfItem.urgentlyHiring::before{content:'';display:inline-block !important;height:20px;padding-right:0.5rem !important;width:20px}[dir='rtl'] .jobCardShelfContainer .jobCardShelf .jobCardShelfItem.earlyApply::after,[dir='rtl'] .jobCardShelfContainer .jobCardShelf .jobCardShelfItem.indeedApply::after,[dir='rtl'] .jobCardShelfContainer .jobCardShelf .jobCardShelfItem.manyApplies::after,[dir='rtl'] .jobCardShelfContainer .jobCardShelf .jobCardShelfItem.openInterviews::after,[dir='rtl'] .jobCardShelfContainer .jobCardShelf .jobCardShelfItem.responsiveEmployer::after,[dir='rtl'] .jobCardShelfContainer .jobCardShelf .jobCardShelfItem.urgentlyHiring::after{content:'';display:inline-block !important;height:20px;padding-right:0.5rem !important;width:20px}.jobCardShelfItem.earlyApply .jobCardShelfIcon{background:url("data:image/svg+xml;charset=utf8,%3Csvg width='20' height='20' fill='none' xmlns='http://www.w3.org/2000/svg'%3E%3Cpath fill-rule='evenodd' clip-rule='evenodd' d='M4 1.563C4 1.252 4.252 1 4.563 1h10.875c.31 0 .562.252.562.563V6.38a.563.563 0 01-.178.41L12.4 10l3.422 3.208a.563.563 0 01.178.41v4.82c0 .31-.252.562-.563.562H4.563A.562.562 0 014 18.437V13.62c0-.156.064-.304.178-.41L7.6 10 4.178 6.792A.562.562 0 014 6.382v-4.82zM6.4 16.75v-2.443l3.6-3.375 3.6 3.375v2.443H6.4z' fill='%237461E7'/%3E%3C/svg%3E") no-repeat !important}.jobCardShelfItem.earlyApply .jobCardShelfIcon svg{opacity:0}.serpvj-earlyApplyMessage-icon::before{background:url("data:image/svg+xml;charset=utf8,%3Csvg width='20' height='20' fill='none' xmlns='http://www.w3.org/2000/svg'%3E%3Cpath fill-rule='evenodd' clip-rule='evenodd' d='M4 1.563C4 1.252 4.252 1 4.563 1h10.875c.31 0 .562.252.562.563V6.38a.563.563 0 01-.178.41L12.4 10l3.422 3.208a.563.563 0 01.178.41v4.82c0 .31-.252.562-.563.562H4.563A.562.562 0 014 18.437V13.62c0-.156.064-.304.178-.41L7.6 10 4.178 6.792A.562.562 0 014 6.382v-4.82zM6.4 16.75v-2.443l3.6-3.375 3.6 3.375v2.443H6.4z' fill='%237461E7'/%3E%3C/svg%3E") no-repeat !important}.serpvj-earlyApplyMessage-icon::before svg{opacity:0}.jobCardShelfItem.indeedApply{background:url("data:image/svg+xml;charset=utf8,%3Csvg width='20' height='20' fill='none' xmlns='http://www.w3.org/2000/svg'%3E%3Cpath d='M18.712 9.627L1.666 3.036c-.36-.14-.756.155-.648.482l1.944 4.617a.22.22 0 00.162.155L10 10l-6.876 1.71c-.072.015-.144.078-.162.14l-1.944 4.633c-.108.326.288.621.648.481l17.046-6.59c.198-.079.288-.219.288-.374s-.09-.295-.288-.373z' fill='%232557A7'/%3E%3C/svg%3E") no-repeat !important}.jobCardShelfItem.indeedApply svg{opacity:0}.jobCardShelfItem.openInterviews{background:url("data:image/svg+xml;charset=utf8,%3Csvg width='20' height='20' fill='none' xmlns='http://www.w3.org/2000/svg'%3E%3Cpath d='M12.258 1.563a.562.562 0 00-.674-.551L1.45 3.065a.563.563 0 00-.45.551v12.768c0 .268.188.498.45.551l10.133 2.054a.562.562 0 00.674-.552V1.563zM19 4.33c0-.621-.503-1.125-1.125-1.125h-4.492v1.688h3.93v10.215h-3.93v1.687h4.492c.622 0 1.125-.504 1.125-1.125V4.33z' fill='%23358271'/%3E%3Cellipse rx='1.126' ry='1.141' transform='matrix(-1 0 0 1 8.88 10)' fill='%23fff'/%3E%3C/svg%3E") no-repeat !i ...
#        </style>
#        <link href="//d3fw5vlhllyvee.cloudfront.net/s/503c00f/jasx.css" rel="stylesheet" type="text/css">
#         <link href="//d3fw5vlhllyvee.cloudfront.net/s/99b0e1b/serp.css" rel="stylesheet" type="text/css"/>
#         <link href="//d3fw5vlhllyvee.cloudfront.net/s/e1a8c5c/jasxreplaceautocompletetest.css" rel="stylesheet" type="text/css"/>
#         <link href="//d3fw5vlhllyvee.cloudfront.net/s/f51866b/jasx_noleftrail_tst.css" rel="stylesheet" type="text/css"/>
#         <style>
#          .seo-breadcrumbs{margin-top:12px;display:flex;justify-content:flex-start;font-size:0.833rem}[dir="ltr"] .seo-breadcrumbs{padding-left:24px}[dir="rtl"] .seo-breadcrumbs{padding-right:24px}.seo-breadcrumbs-centered{margin-top:12px;display:flex;justify-content:flex-start;font-size:0.833rem}body.janus div.seo-breadcrumbs a.seo-breadcrumbLink,body.janus div.seo-breadcrumbs-centered a.seo-breadcrumbLink{color:#000 !important}
#         </style>
#         <style>
#          .jobsearch-PhoneNumberCalloutButton{display:inline-block;position:relative}.jobsearch-PhoneNumberCalloutButton-callout{position:absolute;margin-top:8px}.jobsearch-PhoneNumberCalloutButton-callout .icl-Callout-header::before{display:block;content:'';background:url("/images/phonenumbercalloutbutton/phone.svg") center no-repeat;background-size:18px 18px;padding-left:18px;margin-left:16px}.jobsearch-PhoneNumberCalloutButton-callout .icl-Callout-header::after{display:block;content:'';margin-right:16px}.jobsearch-PhoneNumberCalloutButton-callout .icl-Callout-heading{font-family:"Helvetica Neue",Helvetica,Arial,"Liberation Sans",Roboto,Noto,sans-serif;font-size:1rem;letter-spacing:0;font-weight:700;line-height:1.38;white-space:nowrap}
#         </style>
#         <style type="text/css">
#          [dir] .jobsearch-EmployerFilterTooltip{width:265px;z-index:10;position:absolute;margin-top:-5px}[dir] .jobsearch-EmployerFilterTooltip .icl-Callout-heading{max-width:260px;padding-left:1rem;padding-right:1rem;font-family:"Helvetica Neue",Helvetica,Arial,"Liberation Sans",Roboto,Noto,sans-serif;font-size:0.875rem;letter-spacing:0;font-weight:700;line-height:1.43}[dir] .jobsearch-EmployerFilterTooltip .icl-Callout-close{max-height:44px}[dir] .jobsearch-EmployerFilterTooltip .icl-Callout-actionBar{padding-left:0.5rem;padding-right:0.5rem}[dir] .jobsearch-EmployerFilterTooltip .icl-Callout-actionBar .icl-Callout-action--link{max-width:260px;text-align:start}[dir] .jobsearch-EmployerFilterTooltip--withActions{width:285px;margin-top:10px;margin-left:-20px}[dir] .jobsearch-EmployerFilterTooltip--withActions .icl-Callout-actionBar{flex-direction:column;align-items:flex-start}
#         </style>
#         <style type="text/css">
#          #resultsBody #pageContent #resultsCol .row .location{font-size:1rem;line-height:1.38}.jasxrefreshcombotst #resultsBody #pageContent #resultsCol .row .location{line-height:1.5rem}#resultsBody #pageContent #resultsCol .row .serp-ResponsiveEmployer .serp-ResponsiveEmployer-heading,#resultsBody #pageContent #resultsCol .row .snip .summary,#resultsBody #pageContent #resultsCol .row.unifiedRow .summary{font-size:0.875rem !important;line-height:1.25 !important}#resultsBody #pageContent #resultsCol .row .salarySnippet .salary{font-size:0.875rem;line-height:1.25}.jasxrefreshcombotst #resultsBody #pageContent #resultsCol .row .salarySnippet .salary{line-height:1rem;display:inline-block}#resultsBody #pageContent #resultsCol .row .result-link-bar-container .result-link-bar span,#resultsBody #pageContent #resultsCol .row .result-link-bar-container .result-link-bar a,#resultsBody #pageContent #resultsCol .row .result-link-bar-container .result-link-bar div{font-size:0.75rem !important}#resultsBody #pageContent #resultsCol .row .slNoUnderline{font-size:0.875rem !important;line-height:1 !important}#resultsBody #pageContent #resultsCol .row .jobtitle a{font-size:1.125rem !important;line-height:1.5 !important}#resultsBody #pageContent #resultsCol .row .jobtitle .new,#resultsBody #pageContent #resultsCol .row .iaP .iaLabel{font-size:0.875rem !important;line-height:1.25 !important}.jasxrefreshcombotst #resultsBody #pageContent #resultsCol .row .jobtitle .new{font-size:0.75rem !important;line-height:0.75rem !important}#resultsBody #pageContent #resultsCol .row a.jobtitle{font-size:1.125rem !important;line-height:1.5 !important}#resultsBody #pageContent #resultsCol .row span.new,#resultsBody #pageContent #resultsCol .row .iaP .iaLabel{font-size:0.875rem !important;line-height:1.25 !important}.jasxrefreshcombotst #resultsBody #pageContent #resultsCol .row span.new{font-size:0.75rem !important;line-height:0.75rem !important}.ita-inline-job .sponsored{font-size:0.75rem !important}#resultsBody #pageContent #resultsCol .row .sdn{font-size:0.75rem !important}
#         </style>
#         <link href="//d3fw5vlhllyvee.cloudfront.net/s/45bf26e/jobCardDensityTest.css" rel="stylesheet" type="text/css"/>
#         <style type="text/css">
#          .row .snip .salary,.row .sjcl .salarySnippet span,.row.unifiedRow .salarySnippet .salary{color:#000 !important;font-size:0.875rem;font-weight:bold !important;line-height:1.43rem}
#         </style>
#         <script type="text/javascript">
#          window['mosaicPlatformModel']= {"mosaicReportContentProviderResponse":{"providerId":"mosaic-provider-reportcontent"},"shouldLoadMosaicProviderDockedMessaging":false};
#         </script>
#         <link href="https://d3fw5vlhllyvee.cloudfront.net/mosaic-common/dist/b58063947b6ac4b05566/styles/index.css?cacheKey=1" rel="stylesheet"/>
#         <link href="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-reportcontent/dist/02a37d3b179845f9f30e/css/ReportContent-client.css" rel="stylesheet"/>
#         <link href="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-jsfe-salary/dist/4bda39de9ce541b6f997/css/Main-client.css" rel="stylesheet"/>
#         <link href="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-reportcontent/dist/1d8ac1806f38cc7b6893/css/SerpReportJob-client.css" rel="stylesheet"/>
#         <link href="/images/favicon.ico" rel="shortcut icon"/>
#         <link href="https://fonts.googleapis.com/css?family=Noto+Sans" rel="stylesheet"/>
#         <style type="text/css">
#          body.janus.miniRefresh *,[dir=ltr] body.miniRefresh div .gnav .icl-GlobalFooter-link,[dir=rtl] .gnav .icl-GlobalFooter-link{font-family:'Noto Sans','Helvetica Neue',Helvetica,Arial,sans-serif !important}
#         </style>
#        </link>
#       </link>
#      </link>
#     </link>
#    </link>
#   </link>
#  </head>
#  <body class="ltr jasxcustomfonttst-inactive janus miniRefresh jasxrefreshcombotst" data-tn-application="jasx" data-tn-olth="41be357fa1c7dc26c5ee98836f8950b3" data-tn-originlogid="1eo50shvu98sq800" data-tn-originlogtype="jobsearch">
#   <div aria-label="skip" id="accessibilityBanner" role="navigation">
#    <span id="accessibilityText">
#     Skip to
#     <!-- This is translated before reaching this state -->
#     <a class="accessibilityMenu" href="#jobPostingsAnchor" id="skipToJobs">
#      Job Postings
#     </a>
#     ,
#     <!-- This is translated before reaching this state -->
#     <a class="accessibilityMenu" href="#what" id="skipToSearch">
#      Search
#     </a>
#    </span>
#    <a id="accessibilityClose">
#     Close
#    </a>
#   </div>
#   <script type="text/javascript">
#    createTabBar('1eo50shvu98sq800');
#   </script>
#   <script>
#    var bta = true;
# var sendMeaningfullyInteractive = false;
# var handleBrowserNavigation = true;
# var a11yTwoPaneEnabled = true;
# var deferLogFiring = false;
# var ltr = true;
# var vjsExhibitionModel = new indeed.vjsExhibition('auxCol', a11yTwoPaneEnabled, ltr);
# var vjsStable = true;
# //For SERP jobs, the scope of these job are document
# var showDebug = false;
# var sd = showDebug ? '1' : undefined;
# var viewJobOnSerp = new indeed.vjs('1eo50shvu98sq800', 'vjs', document, vjsExhibitionModel, sd, true, false, bta, a11yTwoPaneEnabled, deferLogFiring);
# var vjk = viewJobOnSerp.getVJK();
# var vjFrom = viewJobOnSerp.getFrom();
# var vjTk = viewJobOnSerp.getTk();
# var indconvtk = '';
# var vjUrl = viewJobOnSerp.vjUrl(vjk, vjFrom, vjTk, indconvtk);
# var showVjOnSerp = vjsStable;
# var zrp = false;
# var viewportTooSmall = true ? window.innerWidth < 960 : window.innerWidth < 1200;
# if ((zrp || !showVjOnSerp || viewportTooSmall) && vjUrl) {
# window.location.replace(vjUrl);
# } else if (showVjOnSerp) {
# initializeTwoPane();
# }
# function initializeTwoPane() {
# var jobKeysWithInfo = {};
#
# jobKeysWithInfo['fd762a165dbd0f62'] = true;
#
# jobKeysWithInfo['4549e9b3baed2940'] = true;
#
# jobKeysWithInfo['43983d5a6adb8f38'] = true;
#
# jobKeysWithInfo['18acbf1ceb1f725b'] = true;
#
# jobKeysWithInfo['0e0c357337accf0d'] = true;
#
# jobKeysWithInfo['18621c0b1136d801'] = true;
#
# jobKeysWithInfo['60ac42ecb98f6c8f'] = true;
#
# jobKeysWithInfo['f893edebfbab2d35'] = true;
#
# jobKeysWithInfo['b4b6b00a9b3934f7'] = true;
#
# jobKeysWithInfo['c5710a695ae1fb4a'] = true;
#
# jobKeysWithInfo['2bed47b83c0a3cf9'] = true;
#
# jobKeysWithInfo['ce7be59e93989952'] = true;
#
# jobKeysWithInfo['51d62be38ba41421'] = true;
#
# jobKeysWithInfo['cd12836b0f139f6b'] = true;
#
# jobKeysWithInfo['9169232a489452e4'] = true;
#
# if (vjk && !jobKeysWithInfo.hasOwnProperty(vjk)) {
# jobKeysWithInfo[vjk] = true;
# }
# if (true) {
# viewJobOnSerp.preloadDescs(jobKeysWithInfo);
# }
# if (handleBrowserNavigation) {
# viewJobOnSerp.browserNavigationHandler();
# }
# window.bindAndRender = function () {
# if (showVjOnSerp) {
# window['2paneEnabled'] = true;
# viewJobOnSerp.bindJobKeys(jobKeysWithInfo, sendMeaningfullyInteractive);
# if (vjUrl) {
# viewJobOnSerp.renderOnJobKey(vjk, 'vjs', '1eo50shvu98sq800', '', undefined, undefined, function () {
# window.location.replace(vjUrl);
# }, function() {
#
# restore('savedjobs');
#
# });
# }
# }
# };
# }
#   </script>
#   <script id="_indeed_gnav_config" type="application/json">
#    {"isEmployer":false,"primaryURL":"https://www.indeed.co.uk/","requestURL":"http://www.indeed.co.uk/jobs?q=business+development\u0026l=london\u0026start=0","from":"gnav-menu-jobsearch--jasx","headerVariant":"DESKTOP_JOBSEEKER","isShowSmallHeader":true,"desktopPageLinks":[{"text":"Find jobs","href":"https://www.indeed.co.uk/","dataHref":"https://www.indeed.co.uk/?from=gnav-jobsearch--jasx","isHighlighted":true,"dataGnavElementName":"FindJobs"},{"text":"Company Reviews","href":"https://www.indeed.co.uk/companies","dataHref":"https://www.indeed.co.uk/companies?from=gnav-jobsearch--jasx","isHighlighted":false,"dataGnavElementName":"CompanyReviews"},{"text":"Find salaries","href":"https://www.indeed.co.uk/salaries","dataHref":"https://www.indeed.co.uk/salaries?from=gnav-jobsearch--jasx","isHighlighted":false,"dataGnavElementName":"FindSalaries"}],"resumeLink":{"text":"Upload your CV","href":"https://www.indeed.co.uk/promo/resume","dataHref":"https://www.indeed.co.uk/promo/resume?from=gnav-jobsearch--jasx","isHighlighted":false,"dataGnavElementName":"UploadYourResume"},"skipNavLinkModel":{"href":"#gnav-header-end","text":"Skip to main content","dataGnavElementName":"SkipNav"},"variantToggleLink":{"text":"Employers / Post Job","href":"https://www.indeed.co.uk/hire?co=GB\u0026hl=en","dataHref":"https://www.indeed.co.uk/hire?co=GB\u0026hl=en\u0026from=gnav-menu-jobsearch--jasx\u0026ikw=gnav-header-hire\u0026isid=employerlink-GB","clickTrackingKey":"EmployersPostJob","dataGnavElementName":"EmployersPostJob"},"country":"GB","logoHref":"/?from=gnav-jobsearch--jasx","logoName":"","appName":"jobsearch--jasx","inboxApiHref":"https://messages.indeed.com/messaging/jobseekers/v2/summary?from=gnav-util-jobsearch--jasx\u0026gnavTK=1eo50si00ste2800\u0026tk=\u0026co=GB\u0026hl=en\u0026clientApp=GNAV","inboxHref":"https://messages.indeed.com?from=gnav-util-jobsearch--jasx\u0026gnavTK=1eo50si00ste2800\u0026tk=\u0026co=GB\u0026hl=en","logRoute":"https://t.indeed.co.uk/gnav/log?from=jobsearch--jasx-serp\u0026parentLogId=1eo50si00ste2800\u0026hostAppTk=","inboxLogTuple":"gnavInbox:12140b7982d032f1660f59e3e976c72d","isInboxTestActive":false,"isShowInboxIcon":false,"inboxTestBucket":-1,"selectedIcon":"","shouldLowerNavIconMinWidth":true,"inboxLogType":"gnavInbox","inboxLth":"12140b7982d032f1660f59e3e976c72d","notificationApiHref":"https://www.indeed.com/notifications/api/1/getNotificationsCount?client=gnav\u0026from=gnav-util-jobsearch--jasx\u0026gnavTK=1eo50si00ste2800\u0026tk=","notificationHref":"https://www.indeed.com/notifications?from=gnav-util-jobsearch--jasx\u0026gnavTK=1eo50si00ste2800\u0026tk=\u0026co=GB\u0026hl=en","isNotificationTestActive":false,"isShowNotificationIcon":false,"notificationTestBucket":-1,"notificationLogType":"gnavNotification","notificationLth":"6d669dfa33371660f3e683b38b9f3ddc","isOnlineStatusActive":false,"onlineStatusApiHref":"https://employers.indeed.com/api/v2/messaging/onlinestatus/jobseeker?indeedcsrftoken=\u0026indeedClientApplication=gnav\u0026isClosed=false","serviceRequestLogUID":"1eo50si00ste2800","hostAppTk":"","canonicalPageId":"","jsErrorLogType":"gnavJSError","jsErrorLth":"6411ec182c6acd8714dc2d03716eed1d","jsEnabledLogType":"gnavJSEnabled","jsEnabledLth":"5e9311c1001227ca5c6c32db123fb854","interactionLogType":"gnavInteraction","interactionLth":"87caa20c31fa9e447264b1615339f1ce","clickLogType":"gnavClick","clickLth":"fa8b0aff9499e52dd7e9215032d9ad9f","pageSpeedLogType":"gnavPageSpeed","pageSpeedLth":"12783140239867f5afc3bd80a743e013","isPageSpeedLoggingEnabled":false,"passportAccountText":"Sign in","passportAccountURL":"https://secure.indeed.com/account/login?hl=en_GB\u0026co=GB\u0026continue=http%3A%2F%2Fwww.indeed.co.uk%2Fjobs%3Fq%3Dbusiness+development%26l%3Dlondon%26start%3D0\u0026tmpl=desktop\u0026service=my\u0026from=gnav-util-jobsearch--jasx","showSecondaryStyleSignInButton":true,"passportDataGnavElementName":"SignIn","language":"en","isShowLanguageSwitcher":false,"googleOneTapModel":{"googleClientId" ...
#   </script>
#   <link href="https://d3fw5vlhllyvee.cloudfront.net/dist/7a77311872208c3472ba/styles/desktop_jobseeker_header_external.css" rel="stylesheet" type="text/css"/>
#   <nav aria-label="Primary" class="gnav" id="gnav-main-container">
#    <div class="main" data-gnav-region="Main" data-reactroot="">
#     <div class="gnav-DesktopHeader is-small-header with-skip-nav">
#      <a class="gnav-SkipNavLink" data-gnav-element-name="SkipNav" href="#gnav-header-end">
#       <span class="gnav-SkipNavLink-text">
#        Skip to main content
#       </span>
#      </a>
#      <div class="gnav-DesktopHeader-logo">
#       <a class="gnav-Logo" data-gnav-element-name="Logo" href="/?from=gnav-jobsearch--jasx" title="">
#        <span class="gnav-sr-only">
#         Indeed logo
#        </span>
#        <div aria-hidden="true" class="gnav-Logo-icon">
#         <span alt="Indeed logo" aria-label="Official Indeed Logo" class="icl-Logo icl-IndeedLogo icl-Logo--wordmark icl-Logo--wordmark--blue icl-Logo--wordmark--sm">
#         </span>
#        </div>
#       </a>
#      </div>
#      <div class="gnav-PageLinks">
#       <a class="gnav-PageLink is-highlighted with-border" data-gnav-action="nav" data-gnav-element-name="FindJobs" data-href="https://www.indeed.co.uk/?from=gnav-jobsearch--jasx" href="https://www.indeed.co.uk/">
#        <span class="gnav-PageLink-text">
#         Find jobs
#        </span>
#       </a>
#       <a class="gnav-PageLink with-border" data-gnav-action="nav" data-gnav-element-name="CompanyReviews" data-href="https://www.indeed.co.uk/companies?from=gnav-jobsearch--jasx" href="https://www.indeed.co.uk/companies">
#        <span class="gnav-PageLink-text">
#         Company Reviews
#        </span>
#       </a>
#       <a class="gnav-PageLink with-border" data-gnav-action="nav" data-gnav-element-name="FindSalaries" data-href="https://www.indeed.co.uk/salaries?from=gnav-jobsearch--jasx" href="https://www.indeed.co.uk/salaries">
#        <span class="gnav-PageLink-text">
#         Find salaries
#        </span>
#       </a>
#      </div>
#      <div class="gnav-DesktopHeader-secondaryLinks">
#       <div class="gnav-ProfileNavLinks">
#       </div>
#       <div class="gnav-ResumeLink">
#        <a class="gnav-PageLink with-border" data-gnav-action="nav" data-gnav-element-name="UploadYourResume" data-href="https://www.indeed.co.uk/promo/resume?from=gnav-jobsearch--jasx" href="https://www.indeed.co.uk/promo/resume">
#         <span class="gnav-PageLink-text">
#          Upload your CV
#         </span>
#        </a>
#       </div>
#       <div class="gnav-LoggedOutAccountLink" data-gnav-element-name="SignIn">
#        <a class="gnav-LoggedOutAccountLink-signIn gnav-PageLink" href="https://secure.indeed.com/account/login?hl=en_GB&amp;co=GB&amp;continue=http%3A%2F%2Fwww.indeed.co.uk%2Fjobs%3Fq%3Dbusiness+development%26l%3Dlondon%26start%3D0&amp;tmpl=desktop&amp;service=my&amp;from=gnav-util-jobsearch--jasx">
#         <span class="gnav-LoggedOutAccountLink-text">
#          Sign in
#         </span>
#        </a>
#       </div>
#       <span class="gnav-Separator gnav-Separator--grey">
#       </span>
#       <div class="gnav-VariantToggleLink-forEmployers">
#        <a class="gnav-PageLink with-border" data-gnav-action="nav" data-gnav-element-name="EmployersPostJob" data-href="https://www.indeed.co.uk/hire?co=GB&amp;hl=en&amp;from=gnav-menu-jobsearch--jasx&amp;ikw=gnav-header-hire&amp;isid=employerlink-GB" href="https://www.indeed.co.uk/hire?co=GB&amp;hl=en">
#         <span class="gnav-PageLink-text">
#          Employers / Post Job
#         </span>
#        </a>
#       </div>
#      </div>
#     </div>
#     <div id="gnav-header-end" tabindex="-1">
#     </div>
#    </div>
#   </nav>
#   <script>
# ...
# /*# sourceMappingURL=Button.css.map*/
#   </style>
#   <div id="resumeCtaFooter" role="complementary" style="height:64px;">
#    <div style="position:absolute;width:100%;">
#     <style type="text/css">
#      .footerCta {
#                         text-align:center;
#                         margin:0;
#                         font-size:0.9375rem;
#                         width:100%;
#                         background-color:#ebebeb;
#                         color:#000000;
#                     }
#
#                     div.content >table {
#                         margin-bottom: 4em;
#                     }
#     </style>
#     <script type="text/javascript">
#      if(null !== call_when_jsall_loaded) {call_when_jsall_loaded(function() {if(!!window.logPromoImpression) {window.logPromoImpression('trk.origin=jobsearch&trk.variant=FooterGrayBelow&trk.pos=below&trk.tk=1eo50shvu98sq800', 'resume');}})}
#     </script>
#     <div class="footerCta greyBar">
#      Let employers find you
#      <style type="text/css">
#       .cta_button {
#             text-decoration:none !important;
#             margin: 12px !important;
#         }
#
#         .cta_button.blue  {
#             color: #f8f8f9 !important;
#         }
#
#         .cta_button.grey {
#             color: #000000 !important;
#         }
#
#         .cta_button.uploaded {
#             border-radius: 100px !important;
#             font-size: 0.75rem;
#             line-height: 1rem;
#             text-align: center;
#             padding: 8px;
#         }
#
#         .cta_button.continue {
#             color: #085ff7 !important;
#             background-color: #ffffff !important;
#             border: 2px solid #195ff7 !important;
#             width: 163px;
#         }
#
#         .cta_button.accept {
#             color: #ffffff !important;
#             background-color: #085ff7 !important;
#             border: 2px solid #085ff7 !important;
#             width: 106px;
#             display: inline-block;
#         }
#
#         .cta_button.back {
#             color: #085ff7 !important;
#             background-color: #ffffff !important;
#             border: 2px solid #cccccc !important;
#             width: 106px;
#             margin-left: -4px !important;
#         }
#      </style>
#      <span dir="ltr">
#       <a class="icl-Button icl-Button--primary icl-Button--sm cta_button blue" href="/promo/resume?from=bottomResumeCTAjobsearch&amp;trk.origin=jobsearch" onclick="if(!!window.logPromoClick) {window.logPromoClick('trk.origin=jobsearch&amp;trk.variant=FooterGrayBelow&amp;trk.pos=below&amp;trk.tk=1eo50shvu98sq800', 'resume','/promo/resume?from=bottomResumeCTAjobsearch&amp;trk.origin=jobsearch');}">
#        Upload your CV
#       </a>
#      </span>
#     </div>
#    </div>
#   </div>
#  </div>
# </div>
# <script type="text/javascript">
#  <!--
#
# logJSVPing('jsv', '1eo50shvu98sq800');
# function jsall_loaded() {
#
#
# initProcessLeftoverDwellEntries();
#
# detectBrowserState('jobsearch', '1eo50shvu98sq800');
#
# initLogTiming('jobsearch', '1eo50shvu98sq800', 'sC680R1SA+Zr242g/4fkohgfaVsQ608z+E8FHpHU0QU=');
# attachSjBlock('');
# attachJaBlock('');
# }
# if (window['closureReady'] === true) {
# jsall_loaded();
# }
# //-->
# </script>
# <script type="text/javascript">
#  PENDING_ANALYTICS_VARS = window.PENDING_ANALYTICS_VARS || [];
# PENDING_ANALYTICS_VARS[PENDING_ANALYTICS_VARS.length] = ['_setCustomVar', 5, 'loggedIn', 'false', 3];
# </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=DC-8232301">
# </script>
# <script>
#  window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'DC-8232301');
# </script>
# <script type="text/javascript">
#  var ga_domains = [];
# ga_domains.push('indeed.co.in');ga_domains.push('indeed.lu');ga_domains.push('indeed.fr');ga_domains.push('indeed.de');ga_domains.push('indeed.com.br');ga_domains.push('indeed.co.uk');ga_domains.push('indeed.hk');ga_domains.push('indeed.fi');ga_domains.push('indeed.pt');ga_domains.push('indeed.jp');ga_domains.push('indeed.com');ga_domains.push('indeed.com.sg');ga_domains.push('indeed.nl');ga_domains.push('indeed.com.pk');ga_domains.push('indeed.cl');ga_domains.push('indeed.es');ga_domains.push('indeed.co.ve');ga_domains.push('indeed.ae');ga_domains.push('indeed.com.mx');ga_domains.push('indeed.com.my');ga_domains.push('indeed.ch');ga_domains.push('indeed.com.co');ga_domains.push('indeed.com.ph');ga_domains.push('indeed.co.za');ga_domains.push('indeed.ie');ga_domains.push('indeed.com.au');ga_domains.push('indeed.ca');ga_domains.push('indeed.com.pe');
#
# (function (i, s, o, g, r, a, m) {
# i['GoogleAnalyticsObject'] = r;
# i[r] = i[r] || function () {
# (i[r].q = i[r].q || []).push(arguments)
# }, i[r].l = 1 * new Date();
# a = s.createElement(o),
# m = s.getElementsByTagName(o)[0];
# a.async = 1;
# a.src = g;
# m.parentNode.insertBefore(a, m)
# })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
# var ga = ga || [];
# ga('create', 'UA-90780-1', 'auto', {
# 'allowLinker': true
# });
# ga('require', 'linkid');
# ga('require', 'linker');
# ga('linker:autoLink', ga_domains, false, true);
# ga('require', 'displayfeatures');
# ga('send', 'pageview');
#
# (function () {
# if (window.PENDING_ANALYTICS_VARS && window.PENDING_ANALYTICS_VARS.length > 0) {
# for (var i in PENDING_ANALYTICS_VARS) {
# ga('set', PENDING_ANALYTICS_VARS[i][2], PENDING_ANALYTICS_VARS[i][3]);
# }
# }
# })();
# </script>
# <script>
#  window._comscore = window._comscore || [];
# window._comscore.push({ c1: "2", c2: "6486505", c4:"www.indeed.co.uk/jobs", c15:"1eo50shv398sq800"});
# (function() { var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true; s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js"; el.parentNode.insertBefore(s, el); })();
# </script>
# <noscript>
#  <img alt="" height="0" src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=6486505&amp;c4=www.indeed.co.uk%2Fjobs&amp;c15=1eo50shv398sq800&amp;cv=2.0&amp;cj=1" style="display:none" width="0"/>
# </noscript>
# <script id="mosaic-init-data" type="text/javascript">
#  window.mosaic= window.mosaic || {};
#     window.mosaic.providers={"mosaic-provider-reportcontent":"https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-reportcontent/dist/3b7aaa1eb9d46fcf7f25/js/ReportContent-client.js","platformJs":"https://d3fw5vlhllyvee.cloudfront.net/mosaic-common/dist/43c5d954bf3133875bd0/scripts/index.js?cacheKey\u003d1","mosaic-provider-jsfe-salary":"https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-jsfe-salary/dist/36970faa515cef6df833/js/Main-client.js","mosaic-provider-serpreportjob":"https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-reportcontent/dist/95bd7c89825731b9c5d4/js/SerpReportJob-client.js"};
#     window.mosaic.providerErrors={};
#     window.mosaic.provideri18N={"mosaic-provider-reportcontent":"https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-reportcontent/dist/i18n/758dab53ab9db670f6c0/en_GB.js","mosaic-provider-jsfe-salary":"https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-jsfe-salary/dist/i18n/8c6a86f54476a9f1b198/en_GB.js","mosaic-provider-serpreportjob":"https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-reportcontent/dist/i18n/758dab53ab9db670f6c0/en_GB.js"};
#     window.mosaic.lazyProviders={"mosaic-provider-reportcontent":"\u003cdiv class\u003d\"reportcontent-injection-wrapper\"\u003e\u003c/div\u003e"};
#     window.mosaic.cssResetProviders={"mosaic-provider-reportcontent":false,"mosaic-provider-jsfe-salary":false,"mosaic-provider-serpreportjob":false};
#     window.mosaic.canaryProviders={"mosaic-provider-reportcontent":false,"mosaic-provider-jsfe-salary":false,"mosaic-provider-serpreportjob":false};
#     window.mosaic.zonedProviders={"salaryFilter":["mosaic-provider-jsfe-salary"],"afterTenthJobResult":[],"jobcards":[],"belowJobResultsPagination":[],"serpModals":[],"belowPageContent":[],"aboveJobCards":["mosaic-provider-serpreportjob"]};
#     window.mosaic.serviceIdLookup={"mosaic-provider-reportcontent":"mosaic-provider-reportcontent","mosaic-provider-jsfe-salary":"mosaic-provider-jsfe-salary","mosaic-provider-serpreportjob":"mosaic-provider-reportcontent"};
#     window.mosaic.shouldLogProviderContainerClicks={"mosaic-provider-reportcontent":false,"mosaic-provider-jsfe-salary":true,"mosaic-provider-serpreportjob":true};
#     window.mosaic.webpackPublicPath="https://d3fw5vlhllyvee.cloudfront.net/mosaic-common/dist";
#     window.mosaic.config = {
#         proctor: {"mosaic_platform_json_as_string_tst":{"name":"inactive","value":-1},"mosaic_platform_load_defer":{"name":"inactive","value":-1}}
#     };
# </script>
# <script id="mosaic-data" type="text/javascript">
#  window.mosaic.providerData={};
#     window.mosaic.initialData = {"logTypes":{"jsuipPlatformInitError":"4327faee2bbb67f4e7f2185701a52e54","mosaicPlatformLoadRecovery":"cee115a2f7013215fe1cde93caa21161","mosaicUserInteraction":"3d8d54584153dd9f2adb9523b9d6135e","mosaicProviderSeen":"e3926cc0a343f384f2e5e6dfc540016a","jsuipProviderLoadTimings":"fb7274d51fc7a04d450086c83a40cc6a","jsuipProviderExecutionError":"211e778edbde5e164fd5f14dd23e6115","jsuipAction":"d5973eb3ad332b3608839e9bbed7d867","jsuipPlatformLoadError":"c74c8d65f1d6f620ddce517edd3faa40","jsuipProviderLoadError":"61c37c1721757c82be5e97b1fff8d1c2"},"platformLogTk":"1eo50si4f98sq800","logTk":"1eo50shvu98sq800","hostId":"jasx","platformId":"jasx","env":"PRODUCTION","pageId":"serp"};
#
#     window.mosaic.providerData["mosaic-provider-reportcontent"]={"hostId":"jasx","pageId":"serp","ctk":"1eo50shv398sq800","country":"GB","language":"en","userAgent":"python-requests/2.24.0","mobvjtk":"1eo50shvu98sq800","isMobile":false,"indeedcsrftoken":"","isLoggedIn":false,"isConfirmed":true,"reportContentApiUrl":"https://reportcontent.indeed.com/api/v1/report/content","showAsButton":false};
#     window.mosaic.providerData["mosaic-provider-jsfe-salary"]={"mobile":false,"currency":"GBP","currencySymbol":"£","salaryType":"YEARLY","salaryFilterLowerBound":0,"salaryFilterUpperBound":120000,"ctk":"1eo50shv398sq800","country":"GB","language":"en","loggedIn":false,"userId":0,"logEntryTK":"1eo50shvu98sq800","privileged":false,"platform":"","url":"https://www.indeed.co.uk/jobs?q=business+development&l=london&start=0","cookie":{"SHOE":"","SOCK":""},"pg":{"mosaic_serp_salary_v11_slider_tst":{"group":"inactive","value":-1,"allocationId":""},"mosaic_serp_salary_v11_minslider_tst":{"group":"active","value":1,"allocationId":"#BC3"},"mosaic_salary_filter_intl_format_tog":{"group":"active","value":1,"allocationId":"#H2"},"mosaic_mobserp_salary_tog":{"group":"inactive","value":-1,"allocationId":""},"mosaic_dserp_salary_tog":{"group":"pill","value":2,"allocationId":"#B9"}},"pgString":"#BC3:mosaic_serp_salary_v11_minslider_tst1,#H2:mosaic_salary_filter_intl_format_tog1,#B9:mosaic_dserp_salary_tog2,mosaic_serp_salary_v11_minslider_tst1,mosaic_salary_filter_intl_format_tog1,mosaic_dserp_salary_tog2","profileAPIPath":"https://profile-api.indeed.com/api","profileAPITimeout":300,"gt":{"split":{}},"locale":"en-GB"};
#     window.mosaic.providerData["mosaic-provider-serpreportjob"]={"hostId":"jasx","pageId":"serp","country":"GB","language":"en","ctk":"1eo50shv398sq800","userAgent":"python-requests/2.24.0","mobvjtk":"1eo50shvu98sq800","isMobile":false,"isLoggedIn":false,"isConfirmed":true,"reportContentApiUrl":"https://reportcontent.indeed.com/api/v1/report/content"};
# </script>
# <script async="" crossorigin="anonymous" src="https://d3fw5vlhllyvee.cloudfront.net/mosaic-common/dist/5f59a25de6a8bba672bf/scripts/loadProviders.js?cacheKey=1">
# </script>
# <script id="mosaic-translation-overrides">
#  this.mosaic = this.mosaic || {}; this.mosaic.i18nOverrides = this.mosaic.i18nOverrides || {};
# </script>
# <script>
#  window['sendPageLoadEndPing'] = function(pageId, tk, st) {var validPageIds = ['viewjob', 'serp']; if (!!Image && validPageIds.indexOf(pageId) > -1 && !!tk && !!st) {var href = '/rpc/pageLoadEnd?pageId=' + pageId + '&tk=' + tk + '&st=' + st + '&__=' + Math.random(); var img = new Image(); img.src = href;}}; window['sendPageLoadEndPing']("serp", "1eo50shvu98sq800", "1606486476798");
# </script>
# <div id="thirdPartyApplyCreateAccountModal">
# </div>
# <div id="successfullySignedInModal">
# </div>

# %%
container = soup.find_all('div', attrs={'class':'tab-container'})
for contain in container:
    print(contain)
    print('*'*30)
# Out:
# <div class="tab-container">
# <div class="sign-in-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# </div>
# ******************************
# <div class="tab-container">
# <div class="sign-in-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# </div>
# ******************************
# <div class="tab-container">
# <div class="sign-in-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# </div>
# ******************************
# <div class="tab-container">
# <div class="sign-in-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# </div>
# ******************************
# <div class="tab-container">
# <div class="more-links-container result-tab" id="tt_display_0" style="display:none;"><div class="more_actions" id="more_0"><ul><li><span class="mat">View all <a href="/Lee-Kum-Kee-(europe)-Ltd-jobs">Lee Kum Kee (Europe) Ltd jobs</a> - <a href="/jobs-in-Canary-Wharf">Canary Wharf jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salaries/business-development-manager-Salaries,-Canary-Wharf-ENG" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=serp-more&amp;fromjk=9169232a489452e4&amp;from=serp-more');">Business Development Manager salaries in Canary Wharf</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/Lee-Kum-Kee-1" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=9169232a489452e4&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=f1c17dc3e06ce7dd');">Lee Kum Kee (Europe) Ltd</a></span></li></ul></div><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('9169232a489452e4'); return false;" title="Close"></a></div><div class="dya-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# <div class="sign-in-container result-tab"></div>
# <div class="notes-container result-tab"></div>
# </div>
# ******************************
# <div class="tab-container">
# <div class="sign-in-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# </div>
# ******************************
# <div class="tab-container">
# <div class="sign-in-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# </div>
# ******************************
# <div class="tab-container">
# <div class="more-links-container result-tab" id="tt_display_1" style="display:none;"><div class="more_actions" id="more_1"><ul><li><span class="mat">View all <a href="/Alogic-jobs">ALOGIC jobs</a> - <a href="/jobs-in-London">London jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salaries/business-development-representative-Salaries,-London-ENG" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=serp-more&amp;fromjk=fd762a165dbd0f62&amp;from=serp-more');">Business Development Representative salaries in London</a></span></li></ul></div><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('fd762a165dbd0f62'); return false;" title="Close"></a></div><div class="dya-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# <div class="sign-in-container result-tab"></div>
# <div class="notes-container result-tab"></div>
# </div>
# ******************************
# <div class="tab-container">
# <div class="more-links-container result-tab" id="tt_display_2" style="display:none;"><div class="more_actions" id="more_2"><ul><li><span class="mat">View all <a href="/Net-Trading-Solutions-Ltd-jobs">Net Trading Solutions Ltd jobs</a> - <a href="/jobs-in-London">London jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salaries/business-development-executive-Salaries,-London-ENG" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=serp-more&amp;fromjk=4549e9b3baed2940&amp;from=serp-more');">Business Development Executive salaries in London</a></span></li></ul></div><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('4549e9b3baed2940'); return false;" title="Close"></a></div><div class="dya-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# <div class="sign-in-container result-tab"></div>
# <div class="notes-container result-tab"></div>
# </div>
# ******************************
# <div class="tab-container">
# <div class="sign-in-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# </div>
# ******************************
# <div class="tab-container">
# <div class="more-links-container result-tab" id="tt_display_3" style="display:none;"><div class="more_actions" id="more_3"><ul><li><span class="mat">View all <a href="/Kevin-Edward-Executive-Search-jobs">Kevin Edward Executive Search jobs</a> - <a href="/jobs-in-London">London jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salaries/business-development-representative-Salaries,-London-ENG" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=serp-more&amp;fromjk=18acbf1ceb1f725b&amp;from=serp-more');">Business Development Representative salaries in London</a></span></li></ul></div><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('18acbf1ceb1f725b'); return false;" title="Close"></a></div><div class="dya-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# <div class="sign-in-container result-tab"></div>
# <div class="notes-container result-tab"></div>
# </div>
# ******************************
# <div class="tab-container">
# <div class="sign-in-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# </div>
# ******************************
# <div class="tab-container">
# <div class="sign-in-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# </div>
# ******************************
# <div class="tab-container">
# <div class="more-links-container result-tab" id="tt_display_4" style="display:none;"><div class="more_actions" id="more_4"><ul><li><span class="mat">View all <a href="/Howard-Kennedy-jobs">Howard Kennedy jobs</a> - <a href="/jobs-in-London">London jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salaries/business-development-executive-Salaries,-London-ENG" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=serp-more&amp;fromjk=2bed47b83c0a3cf9&amp;from=serp-more');">Business Development Executive salaries in London</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/Howard-Kennedy" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=2bed47b83c0a3cf9&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=14c32ea400c6b190');">Howard Kennedy</a></span></li></ul></div><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('2bed47b83c0a3cf9'); return false;" title="Close"></a></div><div class="dya-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# <div class="sign-in-container result-tab"></div>
# <div class="notes-container result-tab"></div>
# </div>
# ******************************
# <div class="tab-container">
# <div class="more-links-container result-tab" id="tt_display_5" style="display:none;"><div class="more_actions" id="more_5"><ul><li><span class="mat">View all <a href="/Central-and-North-West-London-Nhs-Foundation-Trust-jobs">Central and North West London NHS Foundation Trust jobs</a> - <a href="/jobs-in-London">London jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salaries/business-development-manager-Salaries,-London-ENG" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=serp-more&amp;fromjk=ce7be59e93989952&amp;from=serp-more');">Business Development Manager salaries in London</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/Central-and-North-West-London-Nhs-Foundation-Trust" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=ce7be59e93989952&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=b08125336feaaf65');">Central and North West London NHS Foundation Trust</a></span></li><li><span class="mat">See popular <a href="/cmp/Central-and-North-West-London-Nhs-Foundation-Trust/faq" onmousedown="this.href = appendParamsOnce(this.href, '?from=serp-more&amp;campaignid=serp-more&amp;fromjk=ce7be59e93989952&amp;jcid=b08125336feaaf65');">questions &amp; answers about Central and North West London NHS Foundation Trust</a></span></li></ul></div><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('ce7be59e93989952'); return false;" title="Close"></a></div><div class="dya-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# <div class="sign-in-container result-tab"></div>
# <div class="notes-container result-tab"></div>
# </div>
# ******************************

# %% [markdown]
# #### 1.注意这里的 page 变量的使用。
# #### 2.整个过程其实可以写成一个function。

# %% [markdown]
# ##### ？小问题，salary在为空时不会反悔任何内容，这就让title，location，salary之后的排序产生问题

# %%
titles = []
companies = []
# locations = []  # sequence doesn't match others
summaries = []
for page in range(0, 200, 10):
    url = 'https://www.indeed.co.uk/jobs?q=business+development&l=london&start={}'.format(page)
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    for title in soup.find_all('a', attrs={'data-tn-element':'jobTitle'}):
        try:
            titles.append(title.text.strip())
        except:
            titles.append('Nothing')
    for company in soup.find_all('span', attrs={'class':'company'}):
        try:
            companies.append(company.text.strip())
        except:
            companies.append('Nothing')
#     for location in soup.find_all('span', attrs={'class':'location'}):
#         try:
#             locations.append(location.text.strip())
#         except:
#             locations.append('Nothing')
    for summary in soup.find_all("div",{"class":"summary"}):
        try:
            summaries.append(summary.text.strip())
        except:
            summaries.append('Nothing')

# %%
print(len(titles))
print(len(companies))
#print(len(locations))
print(len(summaries))
# Out:
# 308
# 308
# 308

# %%
S_results = pd.DataFrame({'title':titles, 'company':companies, 'summary':summaries})

# %%
S_results
# Out:
#                                                  title  \
# 0                         Sales & Business Development
# 1                         Business Development Manager
# 2       Marketing and Business Development Coordinator
# 3                         Business Development Manager
# 4                       Business Development Executive
# 5                         Business Development Manager
# 6                   Business Development Administrator
# 7    CHL Business Development Manager - Constructio...
# 8                       Business Development Executive
# 9           Junior Business Development Representative
# 10            Business Development Executive & Manager
# 11                        Business Development Manager
# 12                 Business Development Representative
# 13          Business Development & Marketing Assistant
# 14              Strategic Business Development Manager
# 15                      Business Development Associate
# 16                           Business Development Chef
# 17                         Business Development Intern
# 18   Onyx Business Development Analyst & Sales Program
# 19                 Business Development Representative
# 20   Business Development Manager - Media Industry ...
# 21                      Business Development Executive
# 22                    Business Development Evangelists
# 23                        Business Development Manager
# 24                      Business Development Executive
# 25                 Business Development Representative
# 26                 Business Development Representative
# 27                      Business Development Assistant
# 28                Business Development Manager, London
# 29        Sales Support Business Development Associate
# 30                      Business Development Executive
# 31                 Business Development Representative
# 32           Sales, Marketing and Business Development
# 33                        Business Development Manager
# 34                     Business Development Internship
# 35   Business Development Manager -Trauma and Emerg...
# 36                      Business Development Executive
# 37   Business Development Manager - Media Industry ...
# 38            Business Development Representative - UK
# 39                        Business Development Manager
# 40                      Business Development Associate
# 41                      Business Development Assistant
# 42                 Business Development Representative
# 43                 Senior Business Development Manager
# 44                Business Development Manager, London
# 45   Business Development Manager - Media Industry ...
# 46                 Business Development Representative
# 47            Business Development Representative - UK
# 48                      Business Development Executive
# 49                         Business Development Intern
# 50                 Business Development Representative
# 51                        Business Development Manager
# 52           Sales, Marketing and Business Development
# 53                 Business Development Representative
# 54                        Business Development Manager
# 55           Asahi Business Development Executive C004
# 56      Business Development Manager, Amazon Launchpad
# 57   Business Development Manager -Trauma and Emerg...
# 58                      Business Development Executive
# 59   Diageo Grocery Business Development Executive ...
# 60                        Business Development Manager
# 61                        Sales & Business Development
# 62      Marketing and Business Development Coordinator
# 63     Director of Programmes and Business Development
# 64                        Business Development Manager
# 65                      Business Development Executive
# 66                 Business Development Representative
# 67   Business Development Representative (United St...
# 68                 Business Development Representative
# 69   Entry Level Recruiter/Business Development - J...
# 70        Amazon Business Development Graduate Program
# 71               London - Business Development Manager
# 72      Business Development Manager, Amazon Launchpad
# 73                         Junior Business Development
# 74                        Business Development Manager
# 75                        Business Development Manager
# 76                      Business Development Executive
# 77                    New Business Development Manager
# 78                 Lead Business Development Executive
# 79               London - Business Development Manager
# 80                 Senior Business Development Manager
# 81                         Junior Business Development
# 82                      Director, Business Development
# 83       Fixed Income OTC Business Development- Intern
# 84                        Business Development Manager
# 85        Amazon Business Development Graduate Program
# 86                         Business Development Intern
# 87                  Business Development Manager (BDM)
# 88   Hardware Business Development Manager, Devices...
# 89                        Business Development Manager
# 90   Business Development Representative (United St...
# 91                            Business Support Officer
# 92              Associate, Business Development-London
# 93   Inside Sales Associate (Entry Level - Business...
# 94                      Business Development Executive
# 95   INCEPTIAL TECHNOLOGIES UK LIMITED - IT Busines...
# 96   Business Development Manager - Interventional ...
# 97                        Business Development Manager
# 98   Business Development Manager - Media Industry ...
# 99                         Business Development Intern
# 100   Strategic Partner & Business Development Manager
# 101                     Business Development Executive
# 102                           Business Support Officer
# 103  Business Development Representative - West Africa
# 104  Field Sales / Business Development Representat...
# 105                       Business Development Manager
# 106                            Business Change Analyst
# 107                        Business Development Leader
# 108                       Business Development Manager
# 109                       Sales & Business Development
# 110                       Business Development Manager
# 111                Lead Business Development Executive
# 112     Marketing and Business Development Coordinator
# 113    Director of Programmes and Business Development
# 114                   New Business Development Manager
# 115    Business Development Bid Writer and Coordinator
# 116         Marketing & Business Development Assistant
# 117          Asahi Business Development Executive C004
# 118                     Business Development Executive
# 119             Associate, Business Development-London
# 120                       Business Development Manager
# 121                     Business Development Executive
# 122             Business Development and Sales Manager
# 123      Fixed Income OTC Business Development- Intern
# 124                Business Development Representative
# 125                       Business Development Manager
# 126                       Business Development Manager
# 127                     Business Development Executive
# 128                       Business Development Manager
# 129              Business Development Manager - Africa
# 130                                 Business Developer
# 131                     Director, Business Development
# 132           Business Development Manager - Interiors
# 133                       Business Development Manager
# 134       Internship - Business Development UK (m/f/d)
# 135  Inside Sales Associate (Entry Level - Business...
# 136  Business Development Manager - Media Industry ...
# 137                     Business Development Executive
# 138              JJ Media, Business Development London
# 139                       Business Development Manager
# 140                                    Account Manager
# 141  Field Sales / Business Development Representat...
# 142                    Business Development Specialist
# 143  Business Development Executive - Chinese Speak...
# 144                   New Business/Marketing Executive
# 145  Associate / Executive - Business Development (...
# 146                       Business Development Manager
# 147           Business Development - Corporate Actions
# 148                       Business Development Manager
# 149  Business Development Manager - Enterprise Recr...
# 150  Asahi Convenience Business Development Executi...
# 151                     Business Development Assistant
# 152                       Business Development Manager
# 153                   New Business Development Manager
# 154                       Business Development Manager
# 155  Associate - Business Development (Global Corpo...
# 156  Regional Grants & Business Development Coordin...
# 157  Field Sales / Business Development Representat...
# 158                     Business Development Executive
# 159       Business Development Representative (Europe)
# 160  Business Development & Sales | 2021 Summer Intern
# 161          EMEA Business Development Leader - Gaming
# 162                     Business Development Executive
# 163                       Business Development Manager
# 164                Business Development Representative
# 165         Marketing and Business Development Manager
# 166                    Business Development Internship
# 167         Business Development Representative (EMEA)
# 168                Business Development Representative
# 169  Junior Sales – Business Development Representa...
# 170  Field Sales / Business Development Representat...
# 171                       Business Development Manager
# 172                      Business Development Director
# 173                   New Business Development Manager
# 174        Business Development Director Public Sector
# 175                Timber Business Development Manager
# 176                 Account Development Representative
# 177  Business Development Manager: Exhibition and E...
# 178  AppleCare Sales Business Development Manager -...
# 179    Business Development Manager (Home/Field Based)
# 180                     Business Development Executive
# 181                Senior Business Development Manager
# 182                Junior Business Development Manager
# 183        Film Locations, Business Development London
# 184                     Business Development Associate
# 185      Junior Business Development Manager (m/f/div)
# 186                Network Development Account Manager
# 187  Business Developer | Marketing for Business Gr...
# 188  Business Development Manager - Media Industry ...
# 189  Business Development Manager- South, South Eas...
# 190           Business Development Manager (Logistics)
# 191                     Business Development Executive
# 192                     Business Development Executive
# 193  Business Developer | Marketing for Business Gr...
# 194  Business Development Manager Custom Events, Th...
# 195   Specialist - Business Development - Inside Sales
# 196                         VP of Business Development
# 197                     Business Development Executive
# 198                       Business Development Manager
# 199                       Business Development Manager
# 200         Senior Business Development Representative
# 201                Business Development Representative
# 202  Field Sales / Business Development Representat...
# 203  Business Development Associate - French speaki...
# 204            Business Development Executive - London
# 205        Business Development Manager - Telco Sector
# 206             VP Business Development Europe - Fuels
# 207                                 UK Account Manager
# 208                   New Business Development Manager
# 209                                  Account Executive
# 210            Business Development Executive, LE, GBS
# 211                Business Development Representative
# 212      Business Development Manager - Sustainability
# 213                Business Development Representative
# 214  Field Sales / Business Development Representat...
# 215  Air Freight Business Development | Sales Repre...
# 216                     Business Development Associate
# 217  Head of Business Development, Technology Solut...
# 218  Business Development Representative (Swedish s...
# 219                Business Development Representative
# 220              Graduate FinTech Business Development
# 221                       Business Development Manager
# 222                Business Development Manager ( H/F)
# 223                      Paralegal - London & Regional
# 224                          Business Development Lead
# 225  Business Development & Lead Generation (Studen...
# 226           Innovation Business Development Director
# 227       Business Development Representative (London)
# 228                            B2B Key Account Manager
# 229  Vertica Business Development Representative - ...
# 230                       Business Development Manager
# 231  AppleCare Sales Business Development Manager -...
# 232                Senior Business Development Manager
# 233                Business Development Representative
# 234                      Business Development Director
# 235                       Head of Business Development
# 236            Sales & Business Development Internship
# 237     Enterprise Business Development Representative
# 238  Public Policy and Business Development Manager...
# 239  Area Sales and Business Development Manager – ...
# 240  Business Development Manager (Corporate Subscr...
# 241  Business Development Manager, Enterprise (Sout...
# 242                       Business Development Manager
# 243                       Business Development Manager
# 244                               Business Development
# 245                       Business Development Manager
# 246              Business Development Manager - London
# 247  Business Development Executive - Building Mate...
# 248   Specialist - Business Development - Inside Sales
# 249                       Business Development Manager
# 250                       Business Development Manager
# 251                     Business Development Executive
# 252                Business Development Representative
# 253                  Sales & Business Development Lead
# 254                       Business Development Manager
# 255                       Business Development Manager
# 256                       Business Development Manager
# 257             Business Development Account Executive
# 258  Business Development Associate - French speaki...
# 259                       Business Development Manager
# 260                       Business Development Manager
# 261                Business Development Representative
# 262          Business Development Director - Education
# 263                               Business Development
# 264  Business Development Manager - Forensics & Val...
# 265                       Business Development Manager
# 266  Business Development Manager: Exhibition and E...
# 267  AppleCare Sales Business Development Manager -...
# 268  Business Development Manager – Data Business (...
# 269                     Business Development Associate
# 270              Graduate FinTech Business Development
# 271                    Business Development Specialist
# 272                       Business Development Manager
# 273                      Business Development Director
# 274          EMEA Business Development Leader - Gaming
# 275    Business Development Manager (Home/Field Based)
# 276                       Business Development Manager
# 277                 Business Change Officer - JID 9775
# 278                       Business Development Manager
# 279                      Business Development Director
# 280        Business Development Director Public Sector
# 281                   Sales Development Representative
# 282                 Business Development & Growth Lead
# 283                      Business Development Director
# 284  INCEPTIAL TECHNOLOGIES UK LIMITED - IT Busines...
# 285                       Business Development Manager
# 286           Graduate Business Development Consultant
# 287          JTI Business Development Executive PSE003
# 288                     Business Development Executive
# 289  Business Development Manager- South, South Eas...
# 290                       Business Development Manager
# 291           Director Business Development UK (f/m/d)
# 292           Business Development Manager (Logistics)
# 293                       Business Development Manager
# 294  Business Development Manager - Enterprise SaaS...
# 295  Account Development Representative- MuleSoft I...
# 296                       Business Development Manager
# 297                       Business Development Manager
# 298                     Business Development Executive
# 299      Remote-Working Business Development Executive
# 300                    Business Development MBA Intern
# 301                       Business Development Manager
# 302  Junior Business Development Manager (Europe) -...
# 303                     Business Development Executive
# 304                       Business Development manager
# 305                     Business Development Executive
# 306     Business Development Manager - IT and Staffing
# 307                       Business Development Manager
#
#                                                company  \
# 0                            Pitman Training Group Ltd
# 1                                          Single B.V.
# 2                       Royal College of Psychiatrists
# 3                       Ad Hoc Property Management Ltd
# 4                                             Ai-Media
# 5                                    Eye Clinic London
# 6                             Lee Kum Kee (Europe) Ltd
# 7                            Construction Helpline Ltd
# 8                               Careerwise Consultancy
# 9                                               ALOGIC
# 10                           Net Trading Solutions Ltd
# 11                                              Ubiqus
# 12                       Kevin Edward Executive Search
# 13                                      Howard Kennedy
# 14   Central and North West London NHS Foundation T...
# 15                               Law Business Research
# 16                                 Kraft Heinz Company
# 17                            British American Tobacco
# 18                                  Onyx Capital Group
# 19                                          TalentPool
# 20                                     TBD MEDIA GROUP
# 21                              Careerwise Consultancy
# 22                                      Zapkad Pte Ltd
# 23                                       Hiring Wizard
# 24                                             Informa
# 25                                            Filtered
# 26                        Egress Software Technologies
# 27                           Charles Russell Speechlys
# 28                                           Deliveroo
# 29                                 Russell Investments
# 30                                     Michael Page UK
# 31                                          BlackBerry
# 32                                            Finsimco
# 33                                               Wiley
# 34                                   Veritas Prime LLP
# 35                                     MCA Recruitment
# 36                     KINGFISHER CONSULTANCY SERVICES
# 37                                     TBD MEDIA GROUP
# 38                                              Mendix
# 39                                                Beam
# 40                                             UpSlide
# 41                                        Career Legal
# 42                                         Movable Ink
# 43                                           Ferrovial
# 44                                           Deliveroo
# 45                                     TBD MEDIA GROUP
# 46                                         Movable Ink
# 47                                              Mendix
# 48                                      M Square Media
# 49                                     Glassview Media
# 50                                     insightsoftware
# 51                                       Hiring Wizard
# 52                                            Finsimco
# 53                                  Altair Engineering
# 54                                        ThoughtWorks
# 55                                              CPM UK
# 56                             Amazon UK Services Ltd.
# 57                                     MCA Recruitment
# 58                                              KANTAR
# 59                                              CPM UK
# 60                                         Single B.V.
# 61                           Pitman Training Group Ltd
# 62                      Royal College of Psychiatrists
# 63                       Independent Clinical Services
# 64                      Ad Hoc Property Management Ltd
# 65                                      Wood Mackenzie
# 66                                                  N3
# 67                                              PolyAI
# 68                                     insightsoftware
# 69                                             Harnham
# 70                          Amazon EU SARL (UK Branch)
# 71                                   Leyton UK Limited
# 72                             Amazon UK Services Ltd.
# 73                                        EPAM Systems
# 74                                       Iress Limited
# 75                      Ad Hoc Property Management Ltd
# 76                                            Ai-Media
# 77                          Underfloor Heating Express
# 78                                         Quinnox Ltd
# 79                                   Leyton UK Limited
# 80                                           Ferrovial
# 81                                        EPAM Systems
# 82                                                Beam
# 83                                      Deutsche Börse
# 84                  Lockesleys Electrical Services Ltd
# 85                          Amazon EU SARL (UK Branch)
# 86                                          Cosmonauts
# 87                                           Verdantix
# 88                                              Google
# 89                                PillBox Chemists Ltd
# 90                                              PolyAI
# 91                             Red Snapper Recruitment
# 92                                       Hamilton Lane
# 93                                       Medpace, Inc.
# 94                      Creative Parking Solutions Plc
# 95                                     Aspire to Learn
# 96                                 B Braun Medical Ltd
# 97                                                KPMG
# 98                                     TBD MEDIA GROUP
# 99                                     Glassview Media
# 100                                        ActionCOACH
# 101                                            Mobilus
# 102                            Red Snapper Recruitment
# 103                                            Bechtel
# 104                                         BeadMaster
# 105                               Future Science Group
# 106                               Close Brothers Group
# 107                                    Michael Page UK
# 108                                      BEPRO-UK Ltd.
# 109                          Pitman Training Group Ltd
# 110                                        Single B.V.
# 111                                        Quinnox Ltd
# 112                     Royal College of Psychiatrists
# 113                      Independent Clinical Services
# 114                         Underfloor Heating Express
# 115                      Together for Mental Wellbeing
# 116                                         Blue Legal
# 117                                             CPM UK
# 118                                           Ai-Media
# 119                                      Hamilton Lane
# 120                                        Shorten Ltd
# 121                                         Geomiq Ltd
# 122                                         TalentPool
# 123                                     Deutsche Börse
# 124                                           Yepic AI
# 125                                      Iress Limited
# 126                     Ad Hoc Property Management Ltd
# 127                                           Ai-Media
# 128                                         TalentPool
# 129                                       White & Case
# 130                                      TSB MEDIA LTD
# 131                                               Beam
# 132                                    Michael Page UK
# 133                            Human Capital Solutions
# 134                                       COMATCH GmbH
# 135                                      Medpace, Inc.
# 136                                    TBD MEDIA GROUP
# 137                                           Ambition
# 138                                     JJ Media Group
# 139                            BuroHappold Engineering
# 140                                         TalentPool
# 141                                         BeadMaster
# 142                               Loginworks Softwares
# 143                                   Globepay Limited
# 144                                              PRDXN
# 145                       RateGain Travel Technologies
# 146                                             Cision
# 147                                        SmartStream
# 148                                            ISG plc
# 149                                               Syft
# 150                                             CPM UK
# 151                                           Ambition
# 152                                         GlobalData
# 153                                 Red Apple Creative
# 154                                         Navson Ltd
# 155                                               MUFG
# 156                     International Rescue Committee
# 157                                         BeadMaster
# 158                                    L&T Consultancy
# 159                                            UpCloud
# 160                                          Liquidnet
# 161                                             TikTok
# 162                               Media IQ Recruitment
# 163                                             Aspion
# 164                                         Pareto Law
# 165                                     Presented Ltd.
# 166                                          YouShould
# 167                                                D2L
# 168                                           Finastra
# 169                 Institutional Shareholder Services
# 170                                         BeadMaster
# 171                                           Windcave
# 172                         Ernest Hathaway Associates
# 173                                         Brandologi
# 174                                             Kainos
# 175                                       Saint-Gobain
# 176                                          OwnBackup
# 177                               One to One Personnel
# 178                                              Apple
# 179                                              AvA-V
# 180                                       FanHub Media
# 181                                                PwC
# 182                       Daniel Alexander Recruitment
# 183                                     JJ Media Group
# 184                                           Bitstamp
# 185                                               Dept
# 186                                        Phillips 66
# 187                                   Fidabona Limited
# 188                                    TBD MEDIA GROUP
# 189                       Coversure Insurance Services
# 190                                        BJS Haulage
# 191                                         Pareto Law
# 192                          Bluebox Corporate Finance
# 193                                   Fidabona Limited
# 194                    The Economist Newspaper Limited
# 195  The Association of International Certified Pro...
# 196                           ELEMENTS Global Services
# 197                                    Mishcon de Reya
# 198                                    Trinity 365 Ltd
# 199                              World adventure group
# 200                          AWS EMEA SARL (UK Branch)
# 201                                              Trint
# 202                                         BeadMaster
# 203                                             LoopUp
# 204                                            Echobox
# 205                                            Comarch
# 206                                   Menzies Aviation
# 207                                  Leyton UK Limited
# 208                                        SANTORO LTD
# 209                                  WE Communications
# 210                                            Gartner
# 211                                           Granicus
# 212                    The Economist Newspaper Limited
# 213                                              Cvent
# 214                                         BeadMaster
# 215                                        Mainfreight
# 216                            Park Place Technologies
# 217                                             Google
# 218                                         Cloudflare
# 219                                    Pulsar Platform
# 220                                            Neudata
# 221                                         Trustpilot
# 222                               Chateau Cheval Blanc
# 223                                        Accutrainee
# 224                          Kin + Carta Create Europe
# 225                                     GEC Consultant
# 226                                       EPAM Systems
# 227                                Beacon Platform Inc
# 228                                         TalentPool
# 229                                        Micro Focus
# 230             Automated Building and Energy Controls
# 231                                              Apple
# 232                                 Tejas Software Ltd
# 233                                         Partnerize
# 234                                    Thomson Reuters
# 235                              YourPrime Recruitment
# 236                                  Hardware Pioneers
# 237                                            Cutover
# 238                                              Tesla
# 239                                 Headford Growth UK
# 240                               Media IQ Recruitment
# 241                                         SiteMinder
# 242                                    Atalian Servest
# 243                                         Jecca Blac
# 244                                          Donkeyrun
# 245                                          dunnhumby
# 246                                          Relatable
# 247                                     GCS Associates
# 248  The Association of International Certified Pro...
# 249                                    Thomson Reuters
# 250             Automated Building and Energy Controls
# 251                                   TekZam Solutions
# 252                                              Trint
# 253                                Integral Ad Science
# 254                              Photonic Universe Ltd
# 255                            Private Equity Insights
# 256                                         Everbridge
# 257                                           Aviatrix
# 258                                             LoopUp
# 259                                             Aspion
# 260                               PillBox Chemists Ltd
# 261                                              Zafin
# 262                              ISS Facility Services
# 263                            Lionbridge Technologies
# 264                                                BDO
# 265                                          PHS Group
# 266                               One to One Personnel
# 267                                              Apple
# 268                                         Silverdrum
# 269                            Park Place Technologies
# 270                                            Neudata
# 271                             OneAPPS Consulting Ltd
# 272                                        Hanson Wade
# 273                                            M&G plc
# 274                                             TikTok
# 275                                              AvA-V
# 276                               PillBox Chemists Ltd
# 277                                    Spinwell Global
# 278                                      Hiring Wizard
# 279                         Ernest Hathaway Associates
# 280                                             Kainos
# 281                                          Confluent
# 282                                               Beam
# 283                                                SDL
# 284                                    Aspire to Learn
# 285                0.99 Ltd (t/a o99 Training Academy)
# 286                       Celsius Graduate Recruitment
# 287                                             CPM UK
# 288                                           never.no
# 289                       Coversure Insurance Services
# 290                                            Danfoss
# 291                                          Clariness
# 292                                        BJS Haulage
# 293                               Media IQ Recruitment
# 294                                         BlueOptima
# 295                                         Salesforce
# 296                                                POP
# 297                                       Ruella James
# 298                                      Barley Agency
# 299                         The Coaching Masters, Ltd.
# 300                                 Round Hill Capital
# 301                0.99 Ltd (t/a o99 Training Academy)
# 302                                       bookboon.com
# 303                                 Koypo Laboratories
# 304                                     CashLinks ATMs
# 305                                   World News Media
# 306                             Surgecode Software Ltd
# 307                            Private Equity Insights
#
#                                                summary
# 0    Ideally a background in Learning and developme...
# 1    Follow up business leads and identify new sale...
# 2    You should be a strong written and verbal comm...
# 3    Strong command of spoken and written English l...
# 4    Business development: 2 years (Required).\nMot...
# 5    Business development: 1 year (Preferred).\nExc...
# 6    Possible future progression opportunities with...
# 7    Sales/business development: 3 years (Required)...
# 8    Using sales, business development, marketing t...
# 9    Exploring & understanding prospective client n...
# 10   Business development: 1 year (Preferred).\nEff...
# 11   Tracking and following up of relevant market d...
# 12   Interest in financial technology, cloud, datab...
# 13   Assisting lawyers with basic digital tasks suc...
# 14   Through a strategic approach to market and bus...
# 15   Develop relationships with customers to suppor...
# 16   Helping the sales team to pursue new business ...
# 17   Support our Trade Media strategy with external...
# 18   Strong interest in sales, energy and financial...
# 19   Has at least 2 years of experience in business...
# 20   This is predominately a telephone based sales ...
# 21   Using sales, business development, marketing t...
# 22   Business development: 1 year (Preferred).\nExp...
# 23   Proven track record in new business sales.\nTh...
# 24   You must understand the basic business policie...
# 25   You’re organised, have great attention to deta...
# 26   Excellent verbal and written communication ski...
# 27   Excellent communication skills, both written a...
# 28   Be comfortable with targeting new business and...
# 29   A good level of understanding of financial adv...
# 30   Build account plans with key customers to deli...
# 31   Achieve monthly quotas of meetings set and opp...
# 32   Working on our branding and taking ownership o...
# 33   Knowledge of financial markets, compliance and...
# 34   Prospect into strategic business accounts via ...
# 35   Responsible for developing new business and su...
# 36   New home-based, part-time role available at Ki...
# 37   This is predominately a telephone based sales ...
# 38   Excellent phone and written communications ski...
# 39   Owning corporate partnerships for a series of ...
# 40   Experience in sales, business development, par...
# 41   Assist in the creation, development and implem...
# 42   Develop new relationships through email, Linke...
# 43   Ability to understand bid management workings ...
# 44   Be comfortable with targeting new business and...
# 45   This is predominately a telephone based sales ...
# 46   Develop new relationships through email, Linke...
# 47   Excellent phone and written communications ski...
# 48   Make cold calls for new business leads.\nBuild...
# 49   Bachelor's degree in relevant field.\nCritical...
# 50   Conduct high quality and high-volume outbound ...
# 51   Proven track record in new business sales.\nTh...
# 52   Working on our branding and taking ownership o...
# 53   Our customers use our products to solve their ...
# 54   Success is nurturing and sale of win-win value...
# 55   You are able to plan your day and have the dri...
# 56   Own reporting and business development initiat...
# 57   Responsible for developing new business and su...
# 58   The aim of the post is to achieve monthly reve...
# 59   You have are commercially minded and are happy...
# 60   Follow up business leads and identify new sale...
# 61   Ideally a background in Learning and developme...
# 62   You should be a strong written and verbal comm...
# 63   Implementation of the strategic direction of t...
# 64   Strong command of spoken and written English l...
# 65   Verisk (Nasdaq: VRSK) provides data and insigh...
# 66   Excellent oral, written and verbal communicati...
# 67   Build a strong and reliable business developme...
# 68   Conduct high quality and high-volume outbound ...
# 69   Regular fully paid business meetings- meet you...
# 70   Experience in financial analysis, retail buyin...
# 71   Salary £40,000 - £47,500 + Bonus (OTE £70k-£75...
# 72   Own reporting and business development initiat...
# 73   Expected to have a strong interest in software...
# 74   Demonstrable ability to achieve results and wo...
# 75   Strong command of spoken and written English l...
# 76   Business development: 2 years (Required).\nMot...
# 77   Knowledge of the building trade.\nOwn car w/ c...
# 78   Between 5-8 years of relevant experience, over...
# 79   Salary £40,000 - £47,500 + Bonus (OTE £70k-£75...
# 80   Ability to understand bid management workings ...
# 81   Expected to have a strong interest in software...
# 82   You’re analytical and strategic, but someone w...
# 83    Support the day to day product development a...
# 84   Business development: 2 years (Preferred).\nTh...
# 85   Experience in financial analysis, retail buyin...
# 86   Find and build new business leaders and help t...
# 87   Business development: 3 years (Required).\nFor...
# 88   Experience working with hardware, smart home, ...
# 89   Solid numerical skills with the ability to ana...
# 90   Build a strong and reliable business developme...
# 91   To support the senior management team (SMT) ac...
# 92   Good understanding of capital structures, diff...
# 93   May work in tandem with outside business devel...
# 94   Experienced in business development, telesales...
# 95   The candidate must have few years of relevant ...
# 96   To implement best practice within Salesforce f...
# 97   Strong drive and resilience to overcome challe...
# 98   This is predominately a telephone based sales ...
# 99   Bachelor's degree in relevant field.\nCritical...
# 100  Build business processes and systems.\nEstabli...
# 101  The ideal candidate will hold a successful bus...
# 102  To support the senior management team (SMT) ac...
# 103  Directs and actively participates in planning ...
# 104  New business development: 2 years (Required).\...
# 105  Excellent written and spoken English language ...
# 106  Working to support the project managers, busin...
# 107  A new business sales candidate working within ...
# 108  Generate £ 1m + value sales for your former em...
# 109  Ideally a background in Learning and developme...
# 110  Follow up business leads and identify new sale...
# 111  Between 5-8 years of relevant experience, over...
# 112  You should be a strong written and verbal comm...
# 113  Implementation of the strategic direction of t...
# 114  Knowledge of the building trade.\nOwn car w/ c...
# 115  This role will include co-ordinating business ...
# 116  With a high level of business acumen and initi...
# 117  You are able to plan your day and have the dri...
# 118  Business development: 2 years (Required).\nMot...
# 119  Good understanding of capital structures, diff...
# 120  Business development: 1 year (Preferred).\nBus...
# 121  Business development: 1 year (Preferred).\nOur...
# 122  Establish, develop and maintain positive busin...
# 123   Support the day to day product development a...
# 124  Proactively seek new business opportunities in...
# 125  Demonstrable ability to achieve results and wo...
# 126  Strong command of spoken and written English l...
# 127  Business development: 2 years (Required).\nMot...
# 128  Arrange business meetings with prospective cli...
# 129  Excellent written and verbal communication ski...
# 130  Primary duties include identifying business op...
# 131  You’re analytical and strategic, but someone w...
# 132  Min 4-5 Years Proven track record in sales/bus...
# 133  With offices across Europe and London, they pr...
# 134  Great opportunities for personal development a...
# 135  May work in tandem with outside business devel...
# 136  This is predominately a telephone based sales ...
# 137  The role reports into the Senior Business Deve...
# 138  Identifying and suggesting new product develop...
# 139  Raising the company and business profile by re...
# 140  1-2 years of experience in a customer facing r...
# 141  New business development: 2 years (Required).\...
# 142  Excellent analytical skills, strategic thinkin...
# 143  Knowledge of WeChat Pay, Alipay, UnionPay, pay...
# 144  You will be comfortable using a mix of media t...
# 145  Develop creative strategies for engaging and n...
# 146  Identify and proactively call on new business ...
# 147  Commercially astute and able understand busine...
# 148  Assessment, development and implementation of ...
# 149  Business development: 5 years (Required).\n5+ ...
# 150  You are able to plan your day and have the dri...
# 151  The team you will be joining are instrumental ...
# 152  Be a sales hunter prepared to spend 90% of you...
# 153  A proven track record of successful new busine...
# 154  You will able open doors with new accounts to ...
# 155  Good financial and business planning capabilit...
# 156  Work closely with country programs to support ...
# 157  New business development: 2 years (Required).\...
# 158  Business development experience within logisti...
# 159  Outstanding communication skills in all ways: ...
# 160  Work within a team of experienced business dev...
# 161  At least 5 years of game industry business dev...
# 162  As Business Development Executive on the new b...
# 163  Proactive business development techniques to g...
# 164  Identifying and qualifying new business prospe...
# 165  Business development: 1 year (Required).\nEnsu...
# 166  YouShould is recruiting for full time Business...
# 167  Pro-active and goal oriented with the ability ...
# 168  18 month (Minimum) of experience or an interns...
# 169  Leverage social media platforms and other onli...
# 170  New business development: 2 years (Required).\...
# 171  Manage and build relationships with senior bus...
# 172  Seeking a Business Development Director who ca...
# 173  You will develop your own pipeline through tel...
# 174  Negotiating & managing senior stakeholders - Y...
# 175  Build effective relationships with all branch ...
# 176  1-2 years of phone sales/call center experienc...
# 177  Sourcing new leads through B2B telephone work ...
# 178  A strong command of business and financial mod...
# 179  ✴Fully utilising the sales and marketing suppo...
# 180  Ideally you have at least 2-3 years experience...
# 181  Demonstrated experience in a business developm...
# 182  Being actively involved and developing new sal...
# 183  Identifying and suggesting new product develop...
# 184  Experience in institutional sales/business dev...
# 185  Have a good understanding of eCommerce and a b...
# 186  Assist Retail Account Managers with identifyin...
# 187  You might have studied or have experience of s...
# 188  This is predominately a telephone based sales ...
# 189  Developing broker accounts and relationships u...
# 190  Basic salary: £30 - 40kpa (plus competitive co...
# 191  Excellent scope for progression and profession...
# 192  The Business Development Executive reports dir...
# 193  You might have studied or have experience of s...
# 194  Have a deep understanding of the high end cons...
# 195  Develop a comprehensive understanding of busin...
# 196  Proficient business acumen, analytical and org...
# 197  Prepare documentation for business development...
# 198  Create business development strategies; identi...
# 199  Be able to create professional and engaging co...
# 200  Excellent written and verbal communication ski...
# 201  Excellent written and verbal communication ski...
# 202  New business development: 2 years (Required).\...
# 203  Package: Base £26,000 Bonus £8,000, health sch...
# 204  Crafting clearly written business development ...
# 205  Identify, develop and follow-up new business o...
# 206  Previous experience in a fast-moving commercia...
# 207  Develop new business with existing clients and...
# 208  Business development: 1 year (Preferred).\nExc...
# 209  Being an integral part of UK-media und influen...
# 210  Leading complex sales, of large deal sizes, ac...
# 211  Excellent phone and social media communication...
# 212  Experience of new business and account managem...
# 213  Partner with senior sales team to achieve new-...
# 214  New business development: 2 years (Required).\...
# 215  You will be a pivotal member of the Branch, fo...
# 216  Problem Solving - Identifies and analyzes prob...
# 217  Experience in business development related to ...
# 218  Account Executives, Business Development Repre...
# 219  We help companies track, visualize, and unders...
# 220  Profile Fintech, which could lead to a full-ti...
# 221  Generate new business opportunities with prosp...
# 222  A strong track record of new business developm...
# 223  Given the variety of clients we work with, rol...
# 224  Crafted effective strategies and business case...
# 225  Relevant Expertise on all social media platfor...
# 226  Solid experience in business development, cons...
# 227  Interest in financial technology, cloud, datab...
# 228  Tone of voice, and to achieve/maintain the hig...
# 229  Excellent communication skills (e.g. written, ...
# 230  The role will be focused on developing new rel...
# 231  A strong command of business and financial mod...
# 232  Interact with Finance and IT decision makers v...
# 233  Strong in-person, phone, and written customer ...
# 234  Demonstrated successful history selling financ...
# 235  Innovate in the business model as appropriate ...
# 236  Generate leads, through outbound research, fol...
# 237  You can demonstrate how you’ve been successful...
# 238  Forge productive partnerships with business an...
# 239  Field sales experience , within the shipping s...
# 240  2.5 years media sales or subscriptions sales e...
# 241  Consultative selling: You will hold a creative...
# 242  An ability to influence, encourage confidence ...
# 243  Business development: 1 year (Required).\nBeau...
# 244  This role requires you to have some Direct Sal...
# 245  Joining our new business team, you will levera...
# 246  Strong experience with digital culture along w...
# 247  Sector: Consturction Sales - Building Material...
# 248  Develop a comprehensive understanding of busin...
# 249  The UK Business Development Manager will be re...
# 250  The role will be focused on developing new rel...
# 251  Need to make the documents regarding the busin...
# 252  Excellent written and verbal communication ski...
# 253  2+ years of business-related, client-facing ex...
# 254  Leadership skills and aspiration for personal ...
# 255  Have 2+ year of work experience with outstandi...
# 256  5+ years business development experience in th...
# 257  The BD Account Executive will be responsible f...
# 258  Package: Base £26,000 Bonus £8,000, health sch...
# 259  Proactive business development techniques to g...
# 260  Solid numerical skills with the ability to ana...
# 261  Well versed in social media, social selling an...
# 262  Strong results from related commercial or busi...
# 263  We are looking for a target, goal-driven indiv...
# 264  This role supports the Forensic & Valuation Se...
# 265  Experience of selling to service driven busine...
# 266  Sourcing new leads through B2B telephone work ...
# 267  A strong command of business and financial mod...
# 268  We’re seeking an ambitions business developmen...
# 269  Problem Solving - Identifies and analyzes prob...
# 270  Profile Fintech, which could lead to a full-ti...
# 271  O) Research and prepare business cases includi...
# 272  Motivated by targets and always aiming to over...
# 273  Proven track record of business development po...
# 274  At least 5 years of game industry business dev...
# 275  ✴Fully utilising the sales and marketing suppo...
# 276  Solid numerical skills with the ability to ana...
# 277  Work with the Strategic Design Authority to en...
# 278  Proven track record in new business sales.\nTh...
# 279  Seeking a Business Development Director who ca...
# 280  Negotiating & managing senior stakeholders - Y...
# 281  Some experience in a similar business developm...
# 282  >3 years business development or marketing exp...
# 283  This includes identifying and prioritizing cli...
# 284  The candidate must have few years of relevant ...
# 285  Maintaining the business development content.\...
# 286  £23K Basic Salary, OTE £40k in 1st year Benefi...
# 287  Increasing the distribution of Ploom to retail...
# 288  We are looking for candidates with solid and d...
# 289  Developing broker accounts and relationships u...
# 290  Danfoss Heating Segment is looking for a Busin...
# 291  Proven track record in global business develop...
# 292  Basic salary: £30 - 40kpa (plus competitive co...
# 293  4-8 years new business media sales experience....
# 294  Passion for technology and software developmen...
# 295  We are seeking someone who is not afraid of pr...
# 296  Work with the marketing division to participat...
# 297  This is a non-billing role and bonus would be ...
# 298  Business development: 3 years (Required).\nThe...
# 299  This would usually be done via social media me...
# 300  Primarily the role will support the firm’s bus...
# 301  Maintaining the business development content.\...
# 302  Conducting market research on social media and...
# 303  A demonstrable background in sales and busines...
# 304  Good computer skills proficient in Microsoft w...
# 305  Communicating with senior decision-makers.\nSa...
# 306  Business development - IT and Staffing: 1 year...
# 307  Have 2+ year of work experience with outstandi...

# %%
# DF TO EXCEL
from pandas import ExcelWriter

writer = ExcelWriter('PythonExport.xlsx')
yourdf.to_excel(writer,'Sheet5')
writer.save()

# DF TO CSV
yourdf.to_csv('PythonExport.csv', sep=',')

# %%
from pandas import ExcelWriter

# %%
writer = ExcelWriter('PythonExport.xlsx')
S_results.to_excel(writer,'Sheet5')
writer.save()

# %% [markdown]
# salaries = []
# for page in range(0, 100, 10):
#     url = 'https://www.indeed.co.uk/jobs?q=junior+data+scientist&l=london&start={}'.format(page)
#     r = requests.get(url)
#     soup = BeautifulSoup(r.text, 'html.parser')
#     for title in soup.find_all("span","salary no-wrap"):
#         try:
#             salaries.append(title.text.strip())
#         except:
#             salaries.append('No content')

# %% [markdown]
# print(len(salaries))
# print(salaries)

# %% [markdown]
# 需求：把上面的titles和salaries装入一个pandas表格，让title和salary一一对应。

# %% [markdown]
# ##  To be solved
# ##### 我现在能理解，在做之前的project中，for job in soup.find_all('div', attrs={'class':'result'}): 这段代码其实是将每次搜索的范围限制在一个工作内容的卡片中。
# ##### 这样就能自动匹配所有的title,company, salary等等。
# ##### 而我目前还没有找到方法，将每一次的搜索限定在一个小卡片中。所以，如果有某个信息缺失时，之后的信息可能发生错位。

# %%
titles = []
salaries = []
for page in range(0,100,10):
    url = 'https://www.indeed.co.uk/jobs?q=business+development&l=london&start={}'.format(page)
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    for job in soup.find_all('div', attrs={'class':'jobsearch-SerpJobCard unifiedRow row result clickcard'}):
        try:
            titles.append(job.find('a', attrs={'data-tn-element':'jobTitle'}))
        except:
            titles.append(np.nan)
        
        try:
            salaries.append(job.find("span","salary no-wrap"))
        except:
            salaries.append(np.nan)

# %%
# Out:
# []

# %% [markdown]
# UK Indeed 的一个卡片网页代码：
#
# <div class="jobsearch-SerpJobCard unifiedRow row result clickcard" id="pj_1efee661bdfabb84" data-jk="1efee661bdfabb84" data-empn="5951703298586437" data-ci="360037745">
#
# <style>
# .jobcard_logo{margin:6px 0}.jobcard_logo img{width:auto;max-width:80px;max-height:30px}.jasxrefreshcombotst .jobcard_logo img{max-height:2rem;max-width:100%}
# </style>
#
#
# <h2 class="title">
# <a target="_blank" id="sja1" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0DM3XBi8UFNat4xrxKgt90CEA066Pp5zFAvDf-Fs8XmhJTcjHQ7jMqRdWNtbENZjRV9WkydgHWncJ5CoKqvzrslhe_llTJCuEu79pRBDEJ4m1jsjHw76W9m9xg5hQuJMNFHsVES5HdHxCkjFqEykpykvnzeIDVL5kil_CuUinBOX7EBEu3yLVLqi6YKeIdBSsGXGQkZNvjLbVzF0_4iZnCoeNH8yt3hl1-JiQK6XiCk49dMbGhmcB0N8BBvfjbUeNoM4cWkfsfIZZbi-EVkyJ3UfvNfli3sOQGpTTmIVteZKQwVOvsC2n7TdrbmvGVo8CM01xfgEQ86cdYo51SKQdYE8fs5aXUxHfKiwFpi8O2a-i9kmZRwkr6JVjpXW4V5IeJR5DerbNICc6nzMmoRx49D771bqtI_Z2-LBI99mnlwUCA3CavgOZvTt1NlEEBAafC8w8YMrcPODkwtnoTjoI5KraXXoWN6ZDuUnx4tt_AJrCNZOsJlBaIFVihdYLBOYLrenw-t9DSH-A==&amp;p=1&amp;fvj=1&amp;vjs=3" onmousedown="sjomd('sja1'); clk('sja1'); rclk(this,jobmap[1],1);" onclick="setRefineByCookie([]); sjoc('sja1', 1); convCtr('SJ'); rclk(this,jobmap[1],true,1);" rel="noopener nofollow" title="Head of Medical Statistics / Principal Medical Statistician" class="jobtitle turnstileLink " data-tn-element="jobTitle">
# Head of Medical Statistics / Principal Medical Statistician</a>
#
# </h2>
#
# <div class="sjcl">
# <div>
# <span class="company">
# PHMR Ltd</span>
#
# </div>
# <div id="recJobLoc_1efee661bdfabb84" class="recJobLoc" data-rc-loc="London" style="display: none"></div>
# <div class="location accessible-contrast-color-location">London NW1 8XY</div>
# </div>
#
# <div class="salarySnippet salarySnippetDemphasizeholisticSalary">
# <span class="salary no-wrap">
# <span class="salaryText">
# £53,150 - £76,017 a year</span>
# </span>
# </div>
# <div class="jobCardReqContainer"><div class="jobCardReqHeader">Requirements</div><div class="jobCardReqList"><div class="jobCardReqItem">Medical statistics to support HTA/HEOR activities: 5 years</div></div></div><table class="jobCardShelfContainer" role="presentation"><tbody><tr class="jobCardShelf"><td class="jobCardShelfItem indeedApply"><span class="jobCardShelfIcon"><svg width="16" height="16" viewBox="0 0 20 20" fill="none"><rect width="20" height="20" rx="10" fill="#FF5A1F"></rect><path fill-rule="evenodd" clip-rule="evenodd" d="M15.3125 4.0625L10.8125 15.3125L7.99999 11.375L15.3125 4.0625ZM7.604 12.7576L6.875 15.3125L8.567 14.1054L7.604 12.7576ZM7.20463 10.5796L12.419 5.36525L4.0625 9.125L6.9875 10.7968L7.20463 10.5796Z" fill="white"></path></svg></span><span class="iaLabel iaIconActive">Apply with your Indeed CV</span></td></tr></tbody></table><div class="summary">
# <ul style="list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;">
#  <li style="margin-bottom:0px;">Fluency in English (for writing papers, reports, proposals, giving presentations and mentoring <b>junior</b> staff);</li>
#  <li>Good time management and organisational skills.</li>
# </ul></div>
# <div class="jobsearch-SerpJobCard-footer">
# <div class="jobsearch-SerpJobCard-footerActions">
#
# <div class="result-link-bar-container">
# <div class="result-link-bar"><span class="date ">8 days ago</span><span id="tt_set_1" class="tt_set"><div class="job-reaction"><button class="job-reaction-kebab" aria-haspopup="true" aria-expanded="false" data-ol-has-click-handler="" tabindex="0" aria-label="save or dislike" onclick="toggleKebabMenu('1efee661bdfabb84', true, event); return false;"></button><span class="job-reaction-kebab-menu"><button class="job-reaction-kebab-item job-reaction-save" onclick="changeJobState('1efee661bdfabb84', 'save', 'linkbar', true, '');return false;" data-ol-has-click-handler=""><svg focusable="false" viewBox="0 0 24 24" height="16" width="16"><g><path fill="#2d2d2d" d="M16.5,3A6,6,0,0,0,12,5.09,6,6,0,0,0,7.5,3,5.45,5.45,0,0,0,2,8.5C2,12.28,5.4,15.36,10.55,20L12,21.35,13.45,20C18.6,15.36,22,12.28,22,8.5A5.45,5.45,0,0,0,16.5,3ZM12.1,18.55l-0.1.1-0.1-.1C7.14,14.24,4,11.39,4,8.5A3.42,3.42,0,0,1,7.5,5a3.91,3.91,0,0,1,3.57,2.36h1.87A3.88,3.88,0,0,1,16.5,5,3.42,3.42,0,0,1,20,8.5C20,11.39,16.86,14.24,12.1,18.55Z"></path></g></svg><span class="job-reaction-kebab-item-text">Save job</span></button><button class="job-reaction-kebab-item job-reaction-dislike" onclick="dislikeJob(false, false, '1efee661bdfabb84', 'unsave', 'linkbar', true, '');" data-ol-has-click-handler=""><span class="job-reaction-dislike-icon"></span><span class="job-reaction-kebab-item-text">Not interested</span></button><button class="job-reaction-kebab-item job-reaction-report" onclick="reportJob('1efee661bdfabb84');"><span class="job-reaction-report-icon"></span><span class="job-reaction-kebab-item-text">Report job</span></button></span></div></span><div id="editsaved2_1efee661bdfabb84" class="edit_note_content" style="display:none;"></div><script>if (!window['sj_result_1efee661bdfabb84']) {window['sj_result_1efee661bdfabb84'] = {};}window['sj_result_1efee661bdfabb84']['showSource'] = false; window['sj_result_1efee661bdfabb84']['source'] = "Indeed"; window['sj_result_1efee661bdfabb84']['loggedIn'] = true; window['sj_result_1efee661bdfabb84']['showMyJobsLinks'] = true;window['sj_result_1efee661bdfabb84']['undoAction'] = "unsave";window['sj_result_1efee661bdfabb84']['relativeJobAge'] = "8 days ago";window['sj_result_1efee661bdfabb84']['jobKey'] = "1efee661bdfabb84"; window['sj_result_1efee661bdfabb84']['myIndeedAvailable'] = true; window['sj_result_1efee661bdfabb84']['showMoreActionsLink'] = window['sj_result_1efee661bdfabb84']['showMoreActionsLink'] || false; window['sj_result_1efee661bdfabb84']['resultNumber'] = 1; window['sj_result_1efee661bdfabb84']['jobStateChangedToSaved'] = false; window['sj_result_1efee661bdfabb84']['searchState'] = "q=junior data scientist&amp;l=london&amp;start=40"; window['sj_result_1efee661bdfabb84']['basicPermaLink'] = "https://www.indeed.co.uk"; window['sj_result_1efee661bdfabb84']['saveJobFailed'] = false; window['sj_result_1efee661bdfabb84']['removeJobFailed'] = false; window['sj_result_1efee661bdfabb84']['requestPending'] = false; window['sj_result_1efee661bdfabb84']['notesEnabled'] = false; window['sj_result_1efee661bdfabb84']['currentPage'] = "serp"; window['sj_result_1efee661bdfabb84']['sponsored'] = true;window['sj_result_1efee661bdfabb84']['reportJobButtonEnabled'] = false; window['sj_result_1efee661bdfabb84']['showMyJobsHired'] = false; window['sj_result_1efee661bdfabb84']['showSaveForSponsored'] = true; window['sj_result_1efee661bdfabb84']['showJobAge'] = true; window['sj_result_1efee661bdfabb84']['showHolisticCard'] = true; window['sj_result_1efee661bdfabb84']['showDislike'] = true; window['sj_result_1efee661bdfabb84']['showKebab'] = true; window['sj_result_1efee661bdfabb84']['showReport'] = true;</script></div></div>
# </div>
# </div>
#
#
# <div class="tab-container">
# <div class="sign-in-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# </div>
# </div>

# %%
# results = pd.DataFrame({'title':titles, 'salary':salaries})
# results

# %%
# continue tomorrow

# %%
#sdfasdf

# %% [markdown]
# ### companies, salaries, locations, job descriptions

# %%
# bs = soup.find_all('span', attrs={'class':'company'})
# for title in bs:
#     print(title.text.strip())

# %%
# money = []
# bs = soup.find_all("span","salary no-wrap")
# for title in bs:
#     if len(title.text) >3  :
#         money.append(title.text.strip())
#     else:
#         money.append('0')

# %%
# bs = soup.find_all('span', attrs={'class':'location'})
# for title in bs:
#     print(title.text.strip())

# %%
# bs = soup.find_all("div",{"class":"summary"})
# for title in bs:
#     print(title.text.strip())
