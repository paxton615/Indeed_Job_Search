# %% [markdown]
# 1. Introduce the results from Indeed webscrapping here. Excel to df.
# 2.

# %%
import pandas as pd
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# !ls
# Out:
# Indeed_job_search.ipynb               NPL_on_Job_Descriptions.ipynb
# Indeed_job_search_clean_version.ipynb indeed_job_searching_results.xlsx

# %%
# !pwd
# Out:
# /Users/paxton615/Github_Personal/Indeed_Job_Search/Indeed_Job_Search

# %%
df = pd.read_excel(r'/Users/paxton615/Github_Personal/Indeed_Job_Search/Indeed_Job_Search/indeed_job_searching_results.xlsx', index=False)

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.head()
# Out:
#                           title                    company  \
# 0         Junior Data Scientist                  Novafutur
# 1           Junior Data Analyst                   Smarkets
# 2         Junior Data Scientist         Fable Data Limited
# 3  Sr. Data Scientist - ML Labs  AWS EMEA SARL (UK Branch)
# 4                Data Scientist  Amazon Digital UK Limited
#
#                                              summary
# 0  Being a data scientist would require the abili...
# 1  You enjoy collaborating with data scientists, ...
# 2  We need to understand Partner Specific data, M...
# 3  Strong communication and data presentation ski...
# 4  Experience with data scripting languages (e.g....

# %% [markdown]
# ##### Have a look using Counter

# %%
string = "".join(df['summary'])

# %%
print(Counter(string.lower().split()))
# Out:
# Counter({'and': 433, 'data': 333, 'the': 203, 'of': 161, 'to': 129, 'in': 104, 'with': 103, 'a': 93, 'junior': 85, 'other': 79, 'will': 76, 'for': 70, 'team': 65, 'members': 62, 'product': 51, 'mentoring': 50, 'scientists,': 49, 'experience': 48, 'science': 45, 'is': 40, 'scientists': 38, 'machine': 35, 'learning': 34, 'working': 34, 'lead': 34, 'from': 33, 'more': 30, 'technical': 30, 'as': 29, 'on': 29, 'use': 29, 'have': 27, 'our': 26, 'lead,': 25, 'designers': 25, 'two': 25, 'technologies': 25, 'or': 23, 'operations': 23, 'scrum': 23, 'collaboration': 23, 'tech': 23, 'qa': 23, '(engineers,': 23, 'mentor': 22, 'frontend': 22, 'be': 21, 'ability': 19, 'work': 19, 'scientist': 18, 'are': 18, '(e.g.': 17, 'role': 17, 'engineers,': 17, 'coaching': 17, 'develop': 16, 'new': 16, 'supporting': 16, 'skills': 16, 'this': 16, 'engineering': 16, 'complex': 16, 'closely': 16, 'make': 16, 'communicate': 16, 'provide': 16, 'interpret': 16, 'scientific': 15, 'looking': 15, 'business': 15, 'managing': 15, 'some': 15, 'decisions': 15, 'at': 14, 'your': 14, 'broader': 14, 'evaluate': 14, 'users': 14, 'data.': 14, 'analyse': 13, 'assisting': 13, 'platform': 13, 'teams': 13, 'user': 13, 'projects.': 13, 'running': 13, 'design': 13, 'analytics': 13, 'find': 13, 'researchers,': 12, 'computer': 12, 'insights': 12, 'hs3c-compliance': 12, 'transportation': 12, 'around…you’ll': 12, 'clearly': 12, 'effectively': 12, 'specialists': 12, 'own': 12, 'fields': 12, 'automation': 12, 'ngs': 12, 'data…our': 12, 'client’s': 12, 'microservices': 12, 'based,': 12, 'azure,': 12, 'they’re': 12, 'now': 12, 'hire': 12, 'additional': 12, 'developers': 12, 'demonstrable': 12, 'core': 12, 'c#,…developing': 12, 'schema': 12, 'logic': 12, 'team,': 12, 'deputising': 12, 'principal,': 12, 'be…analyse': 12, 'we': 12, 'already': 12, 'hold': 12, 'sources.': 12, "you'll": 12, 'early': 12, 'background,…create,': 12, 'maintain': 12, 'ci/cd': 12, 'pipelines': 12, 'aimed': 12, 'productionizing': 12, 'cases.experience': 12, 'successfully': 12, 'establishing': 12, 'programme': 12, 'research,': 12, 'collaboratively': 12, 'disseminating': 12, 'results': 12, 'essential': 12, 'is…you': 12, 'science/': 12, 'projects': 12, 'perspective.the': 12, 'literature': 12, 'available': 12, 'house': 12, 'studies.': 12, 'mentoring/coaching': 12, 'colleagues…leading': 12, 'alongside': 11, 'side': 11, 'consist': 11, 'guide': 11, 'mid-junior': 11, 'level': 11, 'and…we': 11, 'community': 11, 'finance': 11, 'professionals,': 11, 'quants,': 11, 'designers,': 11, 'engineers.leading': 11, 'an': 10, 'etc).collect,': 10, 'clean': 10, 'up,': 10, 'draw': 10, 'formulate': 10, 'ideas,': 10, 'specialists.postgresql': 10, 'persistent': 10, 'storage.': 10, 'python': 10, 'heavy': 10, 'ingestion': 10, 'components.': 10, 'guidance…you': 10, 'time': 8, 'techniques': 8, 'proposals,': 8, 'etc).the': 8, 'including': 7, 'knowledge': 7, 'senior': 7, 'english': 7, '(for': 7, 'writing': 7, 'papers,': 7, 'reports,': 7, 'giving': 7, 'presentations': 7, 'stakeholders': 7, 'you': 6, 'presentation': 6, 'good': 6, 'within': 6, 'supervision': 6, 'external': 6, 'management': 6, '/': 5, 'communication': 5, 'build': 5, 'key': 5, 'by': 5, 'quantitative': 5, 'team.': 5, 'analytical': 5, 'data-driven': 5, 'processing': 5, 'that': 5, 'staff);': 5, 'organisational': 5, '+': 5, 'being': 4, 'well': 4, 'engineers': 4, 'skills.': 4, 'colleagues.': 4, 'information': 4, 'r': 4, 'marketing': 4, 'services': 4, 'analysis': 4, 'run': 4, 'majority': 4, 'holding': 4, 'phd': 4, 'field.': 4, 'full-time': 4, 'placement': 4, 'significant': 4, 'their': 4, 'strong': 4, 'design,': 4, 'development': 4, 'also': 4, 'warehousing': 4, 'scientists.': 4, 'best': 4, 'platforms': 4, 'analysis,': 4, 'group': 4, 'leading': 4, 'statistical': 4, 'sets.': 4, 'experimental': 4, 'report': 4, 'ori': 4, 'clients.': 4, 'direction': 4, 'existing': 4, 'warehouse': 4, 'big': 3, 'both': 3, 'specific': 3, 'models': 3, 'hiring': 3, 'analyze': 3, 'extract': 3, 'relevant': 3, 'large…exp ...

# %% [markdown]
# ###### Have another look with CountVectorizer

# %%
cvec = CountVectorizer(token_pattern='\w+', stop_words={'data','for','you','to','with','a','the','and','of','in'},
                      ngram_range=(1,2)) #ngram_range=(1,2) 取一个词和相邻的两个词作为统计目标。默认是用每一个词作为统计目标。
cvec.fit([string])  # !!!!!!need to put [] on the string!!!
# Out:
# CountVectorizer(ngram_range=(1, 2),
#                 stop_words={'a', 'and', 'data', 'for', 'in', 'of', 'the', 'to',
#                             'with', 'you'},
#                 token_pattern='\\w+')

# %%
doc_matrx = cvec.transform([string])
doc_matrx
# Out:
# <1x1964 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1964 stored elements in Compressed Sparse Row format>

# %%
cvec.get_feature_names()
# Out:
# ['000',
#  '000 bonus',
#  '000 demonstrable',
#  '1',
#  '1 year',
#  '50',
#  '50 off',
#  '70',
#  '70 75',
#  '70000',
#  '70000 80000',
#  '75',
#  '75 000',
#  '80',
#  '80 000',
#  '80000',
#  '80000 per',
#  'ability',
#  'ability analyse',
#  'ability communicate',
#  'ability provide',
#  'ability working',
#  'able',
#  'able showcase',
#  'across',
#  'across various',
#  'act',
#  'act as',
#  'actively',
#  'actively supports',
#  'activities',
#  'activities as',
#  'activities e',
#  'addition',
#  'addition this',
#  'additional',
#  'additional developers',
#  'advanced',
#  'advanced or',
#  'advice',
#  'advice when',
#  'affiliate',
#  'affiliate program',
#  'affording',
#  'affording freedom',
#  'ai',
#  'ai business',
#  'aimed',
#  'aimed at',
#  'algorithmic',
#  'algorithmic knowledge',
#  'algorithms',
#  'algorithms background',
#  'algorithms strong',
#  'algorithms structures',
#  'algorithms techniques',
#  'all',
#  'all seniority',
#  'alongside',
#  'alongside group',
#  'alongside scientists',
#  'already',
#  'already hold',
#  'also',
#  'also be',
#  'also proficient',
#  'amounts',
#  'amounts real',
#  'an',
#  'an ability',
#  'an algorithms',
#  'an enterprise',
#  'an exciting',
#  'an experienced',
#  'an externally',
#  'an interest',
#  'an sme',
#  'an understanding',
#  'analyse',
#  'analyse big',
#  'analyse draw',
#  'analyse evaluate',
#  'analyse interpret',
#  'analyse process',
#  'analyse we',
#  'analysis',
#  'analysis analyse',
#  'analysis applies',
#  'analysis begin',
#  'analysis eight',
#  'analysis engineer',
#  'analysis hypothesis',
#  'analysis mining',
#  'analysis modeling',
#  'analysis modelling',
#  'analysis training',
#  'analytical',
#  'analytical experts',
#  'analytical skills',
#  'analytical warehouse',
#  'analytics',
#  'analytics causalens',
#  'analytics engineers',
#  'analytics solutions',
#  'analytics systems',
#  'analyze',
#  'analyze extract',
#  'annual',
#  'annual membership',
#  'annum',
#  'annum plus',
#  'applications',
#  'applications include',
#  'applies',
#  'applies project',
#  'apply',
#  'apply enjoy',
#  'apply statistical',
#  'apply their',
#  'appreciation',
#  'appreciation runnin',
#  'appreciation running',
#  'approaches',
#  'approaches proposals',
#  'appropriate',
#  'appropriate structure',
#  'architectural',
#  'architectural discussions',
#  'architectures',
#  'architectures i',
#  'are',
#  'are also',
#  'are an',
#  'are community',
#  'are currently',
#  'are deeply',
#  'are familiar',
#  'are looking',
#  'around',
#  'around collection',
#  'around common',
#  'around ll',
#  'art',
#  'art nlp',
#  'art systems',
#  'artificial',
#  'artificial intelligence',
#  'as',
#  'as 70',
#  'as apply',
#  'as are',
#  'as driving',
#  'as external',
#  'as is',
#  'as junior',
#  'as manage',
#  'as needed',
#  'as part',
#  'as required',
#  'as scientist',
#  'as senior',
#  'as software',
#  'as well',
#  'aspects',
#  'aspects existing',
#  'aspects management',
#  'assist',
#  'assist customisation',
#  'assistants',
#  'assistants interns',
#  'assisting',
#  'assisting development',
#  'assisting frontend',
#  'assisting wider',
#  'at',
#  'at least',
#  'at productionizing',
#  'at smarkets',
#  'aura',
#  'aura uk',
#  'automated',
#  'automated security',
#  'automation',
#  'automation engineers',
#  'available',
#  'available house',
#  'azure',
#  'azure they',
#  'background',
#  'background build',
#  'background create',
#  'background knowledge',
#  'bar',
#  'bar is',
#  'based',
#  'based running',
#  'basic',
#  'basic salary',
#  'be',
#  'be able',
#  'be analyse',
#  'be expected',
#  'be full',
#  'be mentoring',
#  'be responsible',
#  'be working',
#  'begin',
#  'begin undertake',
#  'being',
#  'being an',
#  'being responsible',
#  'being scientist',
#  'benefits',
#  'benefits being',
#  'best',
#  'best practice',
#  'best practices',
#  'best practise',
#  'better',
#  'better models',
#  'better strong',
#  'beyond',
#  'beyond numbers',
#  'big',
#  'big algorithmic',
#  'big architectures',
#  'big prior',
#  'big sets',
#  'biggest',
#  'biggest sets',
#  'billable',
#  'billable activities',
#  'bonus',
#  'bonus benefits',
#  'both',
#  'both hands',
#  'both internal',
#  'both real',
#  'broader',
#  'broader hs3c',
#  'broader science',
#  'build',
#  'build deploy',
#  'build intelligent',
#  'build next',
#  'build platform',
#  'build valuable',
#  'building',
#  'building end',
#  'building expanding',
#  'business',
#  'business logic',
#  'business opportunities',
#  'business that',
#  'business users',
#  'but',
#  'but they',
#  'by',
#  'by designing',
#  'by scientists',
#  'c',
#  'c developing',
#  'can',
#  'can make',
#  'candidate',
#  'candidate will',
#  'candidates',
#  'candidates all',
#  'candidates lead',
#  'capability',
#  'capability including',
#  'capable',
#  'capable using',
#  'capacity',
#  'capacity mentoring',
#  'capturing',
#  'capturing requirements',
#  'career',
#  'career as',
#  'cases',
#  'cases experience',
#  'cases mentor',
#  'cash',
#  'cash plan',
#  'causalens',
#  'causalens is',
#  'cd',
#  'cd pipelines',
#  'cell',
#  'cell lines',
#  'centred',
#  'centred eight',
#  'challenges',
#  'challenges mentor',
#  'challenges presented',
#  'challenging',
#  'challenging contributing',
#  'challenging role',
#  'chance',
#  'chance get',
#  'checkout',
#  'checkout com',
#  'chemical',
#  'chemical properties',
#  'ci',
#  'ci cd',
#  'clean',
#  'clean up',
#  'cleaning',
#  'cleaning managing',
#  'cleansing',
#  'cleansing filtering',
#  'clearly',
#  'clearly effectively',
#  'client',
#  'client feedback',
#  'client s',
#  'clients',
#  'clients ability',
#  'clients will',
#  'closely',
#  'closely broader',
#  'closely collaborate',
#  'closely engineers',
#  'closely junior',
#  'co',
#  'co operate',
#  'coach',
#  'coach mentor',
#  'coaching',
#  'coaching junior',
#  'coaching mentoring',
#  'coaching supporting',
#  'collaborate',
#  'collaborate other',
#  'collaborating',
#  'collaborating as',
#  'collaborating scientists',
#  'collaboration',
#  'collaboration product',
#  'collaboratively',
#  'collaboratively other',
#  'collate',
#  'collate analyse',
#  'colleagues',
#  'colleagues across',
#  'colleagues act',
#  'colleagues analyze',
#  'colleagues best',
#  'colleagues develop',
#  'colleagues leading',
#  'colleagues performance',
#  'collect',
#  'collect clean',
#  'collecting',
#  'collecting new',
#  'collection',
#  'collection using',
#  'com',
#  'com is',
#  'combine',
#  'combine office',
#  'coming',
#  'coming from',
#  'commercial',
#  'commercial challenges',
#  'common',
#  'common purpose',
#  'communicate',
#  'communicate clearly',
#  'communicate complex',
#  'communicate other',
#  'communicate work',
#  'communication',
#  'communication presentation',
#  'community',
#  'community assisting',
#  'community finance',
#  'complete',
#  'complete multiple',
#  'complex',
#  'complex analysis',
#  'complex ci',
#  'complex from',
#  'complex scientific',
#  'compliance',
#  'compliance technologies',
#  'component',
#  'component chance',
#  'components',
#  'components mentoring',
#  'computer',
#  'computer science',
#  'computer scientists',
#  'computing',
#  'computing we',
#  'conceptual',
#  'conceptual approaches',
#  'concurrent',
#  'concurrent algorithms',
#  'consist',
#  'consist assisting',
#  'consumer',
#  'consumer rider',
#  'consumption',
#  'consumption using',
#  'contributing',
#  'contributing internal',
#  'core',
#  'core skills',
#  'create',
#  'create centred',
#  'create develop',
#  'creators',
#  'creators traders',
#  'cross',
#  'cross functional',
#  'cs',
#  'cs fundamentals',
#  'curation',
#  'curation presentation',
#  'currently',
#  'currently working',
#  'customer',
#  'customer analytics',
#  'customer focus',
#  'customers',
#  'customers needs',
#  'customers trial',
#  'customisation',
#  'customisation product',
#  'dataset',
#  'dataset curation',
#  'decision',
#  'decision making',
#  'decisions',
#  'decisions architectural',
#  'decisions around',
#  'decisions quickly',
#  'deeply',
#  'deeply senior',
#  'define',
#  'define implement',
#  'delivering',
#  'delivering exceptional',
#  'delivery',
#  'delivery capability',
#  'delivery projects',
#  'demonstrable',
#  'demonstrable analytical',
#  'demonstrable core',
#  'dental',
#  'dental cash',
#  'department',
#  'department as',
#  'deploy',
#  'deploy machine',
#  'deputising',
#  'deputising team',
#  'design',
#  'design appropriate',
#  'design conceptual',
#  'design concurrent',
#  'design evangelize',
#  'design interpret',
#  'design maintenance',
#  'designers',
#  'designers analytics',
#  'designers design',
#  'designers etc',
#  'designers experience',
#  'designing',
#  'designing as',
#  'designing productising',
#  'designs',
#  'designs but',
#  'detailed',
#  'detailed analysis',
#  'determine',
#  'determine customers',
#  'develop',
#  'develop better',
#  'develop maintain',
#  'develop stable',
#  'develop tools',
#  'developed',
#  'developed proficiency',
#  'developer',
#  'developer create',
#  'developers',
#  'developers demonstrable',
#  'developing',
#  'developing schema',
#  'development',
#  'development 50',
#  'development big',
#  'development career',
#  'development others',
#  'development prognostic',
#  'development research',
#  'different',
#  'different sources',
#  'direct',
#  'direct other',
#  'direction',
#  'direction supervision',
#  'disciplines',
#  'disciplines goal',
#  'discussions',
#  'discussions strong',
#  'disseminating',
#  'disseminating results',
#  'distributed',
#  'distributed system',
#  'document',
#  'document large',
#  'draw',
#  'draw insights',
#  'drive',
#  'drive cross',
#  'driven',
#  'driven decisions',
#  'driven mindset',
#  'driven way',
#  'driven working',
#  'driving',
#  'driving key',
#  'e',
#  'e g',
#  'e nosql',
#  'early',
#  'early science',
#  'early stage',
#  'effectively',
#  'effectively specialists',
#  'eight',
#  'eight bar',
#  'end',
#  'end end',
#  'end machine',
#  'end proven',
#  'end users',
#  'energy',
#  'energy consumption',
#  'enforce',
#  'enforce automated',
#  'engineer',
#  'engineer will',
#  'engineering',
#  'engineering dataset',
#  'engineering leading',
#  'engineering or',
#  'engineering science',
#  'engineering subject',
#  'engineers',
#  'engineers leading',
#  'engineers majority',
#  'engineers marketers',
#  'engineers ngs',
#  'engineers productionise',
#  'engineers scientist',
#  'engineers scientists',
#  'engineers will',
#  'english',
#  'english writing',
#  'enjoy',
#  'enjoy collaborating',
#  'entails',
#  'entails working',
#  'enterprise',
#  'enterprise hub',
#  'environment',
#  'environment strong',
#  'equivalent',
#  'equivalent scientists',
#  'essential',
#  'essential as',
#  'establishing',
#  'establishing programme',
#  'etc',
#  'etc analyse',
#  'etc collect',
#  'etc excellent',
#  'etc fluency',
#  'etc other',
#  'etc will',
#  'evaluate',
#  'evaluate from',
#  'evaluate make',
#  'evaluated',
#  'evaluated modelling',
#  'evangelize',
#  'evangelize as',
#  'event',
#  'event fluency',
#  'excellent',
#  'excellent skills',
#  'excellent verbal',
#  'exceptional',
#  'exceptional work',
#  'exchange',
#  'exchange that',
#  'exciting',
#  'exciting early',
#  'exciting start',
#  'exec',
#  'exec at',
#  'existing',
#  'existing analytical',
#  'existing sets',
#  'expanding',
#  'expanding warehouses',
#  'expected',
#  'expected leverage',
#  'experience',
#  'experience analysis',
#  'experience cleansing',
#  'experience designers',
#  'experience driven',
#  'experience hiring',
#  'experience is',
#  'experience maintaining',
#  'experience managing',
#  'experience mentoring',
#  'experience modelling',
#  'experience more',
#  'experience multiple',
#  'experience science',
#  'experience scripting',
#  'experience streaming',
#  'experience successfully',
#  'experience technical',
#  'experience visualization',
#  'experience working',
#  'experienced',
#  'experienced product',
#  'experienced scientist',
#  'experimental',
#  'experimental report',
#  'expert',
#  'expert appreciation',
#  'expert within',
#  'expertise',
#  'expertise scientific',
#  'expertise train',
#  'experts',
#  'experts have',
#  'extensive',
#  'extensive knowledge',
#  'external',
#  'external clients',
#  'external stakeholders',
#  'externally',
#  'externally facing',
#  'extract',
#  'extract relevant',
#  'extraction',
#  'extraction pipelines',
#  'extrapolation',
#  'extrapolation time',
#  'facets',
#  'facets science',
#  'facing',
#  'facing exchange',
#  'factoring',
#  'factoring complex',
#  'familiar',
#  'familiar at',
#  'features',
#  'features models',
#  'features than',
#  'feedback',
#  'feedback into',
#  'fees',
#  'fees one',
#  'field',
#  'field this',
#  'fields',
#  'fields e',
#  'filtering',
#  'filtering re',
#  'finance',
#  'finance professionals',
#  'find',
#  'find extrapolation',
#  'find new',
#  'fluency',
#  'fluency english',
#  'focus',
#  'focus coach',
#  'forecasting',
#  'forecasting predicting',
#  'formulate',
#  'formulate ideas',
#  'freedom',
#  'freedom responsibility',
#  'from',
#  'from an',
#  'from different',
#  'from ground',
#  'from heterogeneous',
#  'from large',
#  'from technical',
#  'from work',
#  'from your',
#  'frontend',
#  'frontend lead',
#  'frontend team',
#  'full',
#  'full stack',
#  'full time',
#  'functional',
#  'functional teams',
#  'functional working',
#  'fundamental',
#  'fundamental physical',
#  'fundamentals',
#  'fundamentals including',
#  'g',
#  'g automation',
#  'g design',
#  'g mass',
#  'g sql',
#  'g supervise',
#  'generation',
#  'generation models',
#  'get',
#  'get involved',
#  'giving',
#  'giving presentations',
#  'goal',
#  'goal delivering',
#  'good',
#  'good manipulation',
#  'good time',
#  'good working',
#  'googling',
#  'googling stackoverflowing',
#  'governance',
#  'governance best',
#  'governance other',
#  'graduate',
#  'graduate scientists',
#  'great',
#  'great designs',
#  'ground',
#  'ground up',
#  'group',
#  'group build',
#  'group experienced',
#  'group strategists',
#  'grow',
#  'grow junior',
#  'guidance',
#  'guidance sharing',
#  'guidance team',
#  'guidance will',
#  'guide',
#  'guide two',
#  'gym',
#  'gym annual',
#  'hackathons',
#  'hackathons some',
#  'hadoop',
#  'hadoop etc',
#  'hands',
#  'hands on',
#  'harnham',
#  'harnham are',
#  'has',
#  'has developed',
#  'have',
#  'have ability',
#  'have passion',
#  'have some',
#  'have strong',
#  'health',
#  'health dental',
#  'heavy',
#  'heavy ingestion',
#  'help',
#  'help build',
#  'help understand',
#  'heterogeneous',
#  'heterogeneous producers',
#  'hire',
#  'hire two',
#  'hiring',
#  'hiring or',
#  'hold',
#  'hold on',
#  'holding',
#  'holding phd',
#  'house',
#  'house design',
#  'how',
#  'how use',
#  'hs3c',
#  'hs3c compliance',
#  'hub',
#  'hub an',
#  'hypothesis',
#  'hypothesis testing',
#  'i',
#  'i e',
#  'ideas',
#  'ideas working',
#  'identify',
#  'identify pursue',
#  'imagery',
#  'imagery video',
#  'implement',
#  'implement best',
#  'implement enforce',
#  'implementation',
#  'implementation analysis',
#  'improving',
#  'improving pipelines',
#  'include',
#  'include both',
#  'including',
#  'including an',
#  'including capturing',
#  'including cleaning',
#  'including good',
#  'including lipophilicity',
#  'including non',
#  'including pipeline',
#  'individuals',
#  'individuals forecasting',
#  'information',
#  'information from',
#  'information services',
#  'ingestion',
#  'ingestion components',
#  'insights',
#  'insights formulate',
#  'insights will',
#  'inspire',
#  'inspire mentor',
#  'intelligence',
#  'intelligence experience',
#  'intelligence system',
#  'intelligent',
#  'intelligent decision',
#  'interest',
#  'interest machine',
#  'interest mentoring',
#  'interest scientific',
#  'internal',
#  'internal customer',
#  'internal external',
#  'internal stakeholders',
#  'interns',
#  'interns senior',
#  'interpret',
#  'interpret experimental',
#  'interpret studies',
#  'into',
#  'into managing',
#  'involved',
#  'involved actively',
#  'is',
#  'is essential',
#  'is full',
#  'is group',
#  'is looking',
#  'is microservices',
#  'is open',
#  'is plus',
#  'is recruiting',
#  'is run',
#  'is will',
#  'isn',
#  'isn t',
#  'its',
#  'its provide',
#  'junior',
#  'junior colleagues',
#  'junior engineers',
#  'junior graduate',
#  'junior individuals',
#  'junior level',
#  'junior marketing',
#  'junior members',
#  'junior other',
#  'junior positions',
#  'junior scientists',
#  'junior senior',
#  'junior staff',
#  'junior support',
#  'junior team',
#  'junior train',
#  'junior training',
#  'junior will',
#  'just',
#  'just shipping',
#  'key',
#  'key platform',
#  'key role',
#  'key strategic',
#  'key technologies',
#  'knowledge',
#  'knowledge algorithms',
#  'knowledge big',
#  'knowledge building',
#  'knowledge extraction',
#  'knowledge processing',
#  'lab',
#  'lab component',
#  'lake',
#  'lake warehouse',
#  'land',
#  'land services',
#  'language',
#  'language processing',
#  'language python',
#  'languages',
#  'languages e',
#  'large',
#  'large amounts',
#  'large experience',
#  'large sets',
#  'large significant',
#  'large volumes',
#  'lead',
#  'lead inspire',
#  'lead mentor',
#  'lead other',
#  'lead qa',
#  'leadership',
#  'leadership capacity',
#  'leading',
#  'leading mentoring',
#  'leading operations',
#  'leading technical',
#  'learning',
#  'learning big',
#  'learning mining',
#  'learning ml',
#  'learning models',
#  'learning or',
#  'learning presentation',
#  'learning principles',
#  'learning projects',
#  'learning solutions',
#  'learning specialists',
#  'least',
#  'least some',
#  'level',
#  'level members',
#  'levels',
#  'levels junior',
#  'leverage',
#  'leverage their',
#  'lines',
#  'lines lvvs',
#  'lipophilicity',
#  'lipophilicity solubility',
#  'literate',
#  'literate organisation',
#  'literature',
#  'literature available',
#  'll',
#  'll have',
#  'll work',
#  'logic',
#  'logic coaching',
#  'looking',
#  'looking an',
#  'looking hire',
#  'looking senior',
#  'looking top',
#  'lvvs',
#  'lvvs this',
#  'machine',
#  'machine learning',
#  'machines',
#  'machines optimise',
#  'main',
#  'main platforms',
#  'maintain',
#  'maintain complex',
#  'maintaining',
#  'maintaining improving',
#  'maintenance',
#  'maintenance governance',
#  'majority',
#  'majority holding',
#  'make',
#  'make decisions',
#  'make driven',
#  'make marketing',
#  'make sure',
#  'making',
#  'making machines',
#  'manage',
#  'manage communicate',
#  'management',
#  'management e',
#  ...]

# %%
len(cvec.get_feature_names())
# Out:
# 1964

# %%
print('Number of nonzero entries:')
print(doc_matrx.nnz)
print('Highest count:')
print(doc_matrx.max())
print('Row means:')
print(doc_matrx.mean(axis=1))
print('Transform to numpy array format:')
print(doc_matrx.toarray())
# Out:
# Number of nonzero entries:
# 1964
# Highest count:
# 103
# Row means:
# [[4.58095723]]
# Transform to numpy array format:
# [[ 3  2  1 ... 12  1  1]]

# %%
df_rank = pd.DataFrame(cvec.transform([string]).toarray(),
                      columns=cvec.get_feature_names())

# %%
df_rank
# Out:
#    000  000 bonus  000 demonstrable  1  1 year  50  50 off  70  70 75  70000  \
# 0    3          2                 1  2       2   2       2   2      2      1
#
#    ...  writing papers  written  written communication  year  year experience  \
# 0  ...               7        1                      1     3                1
#
#    year work  your  your own  your solutions  your team
# 0          2    14        12               1          1
#
# [1 rows x 1964 columns]

# %%
df_rank.transpose().sort_values(0,ascending=False).transpose()
# Out:
#    junior  scientists  team  other  will  experience  mentoring  members  \
# 0     103          92    83     79    76          70         64       64
#
#    lead  science  ...  nosql  non billable  new modelling  nlp topics  \
# 0    59       58  ...      1             1              1           1
#
#    nlp techniques  nlp researching  next generation  next  collaborating as  \
# 0               1                1                1     1                 1
#
#    your team
# 0          1
#
# [1 rows x 1964 columns]

# %% [markdown]
# #####
